# %%
import sys; sys.path.insert(0,'/Users/ryan/github/prosodic/')
import sys; sys.path.insert(0,'/Users/ryan/github/cadence/')
from cadence.imports import *
# !rm -rf {PATH_DB}

# %%
# text = Text(sonnet,linebreaks=False,phrasebreaks=True)
# text = Text("And spends his prodigal wits in bootless rhyme")
# text = Text("and spends his mighty wits in bootless rhyme")
# text = Text("once upon a midnight dreary")
# text = Text("The bloody spur cannot provoke him on")
text = Verse(sonnet)
doc = text.para(1)
doc
# Out:
# <Paragraph/Stanza #1: “How heavy do I journey on the way, When what I seek, my weary travel's end, Doth teach that ease and that repose to say 'Thus far the miles are measured from thy friend!'...” (2 sents, 118 words)>

# %%
text.words(1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1, 1, 1, 1, 1, , How, how), (1, 1, 1, 1, 2,  , heavy, heavy), (1, 1, 1, 1, 3,  , do, do), (1, 1, 1, 1, 4,  , I, i), (1, 1, 1, 1, 5,  , journey, journey), (1, 1, 1, 1, 6,  , on, on), (1, 1, 1, 1, 7,  , the, the), (1, 1, 1, 1, 8,  , way,, way), (1, 1, 2, 2, 9,
#  , When, when), (1, 1, 2, 2, 10,  , what, what), (1, 1, 2, 2, 11,  , I, i), (1, 1, 2, 2, 12,  , seek,, seek), (1, 1, 3, 2, 13,  , my, my), (1, 1, 3, 2, 14,  , weary, weary), (1, 1, 3, 2, 15,  , travel's, travels), (1, 1, 3, 2, 16,  , end,, end), (1, 1, 4, 3, 17,
#  , Doth, doth), (1, 1, 4, 3, 18,  , teach, teach), (1, 1, 4, 3, 19,  , that, that), (1, 1, 4, 3, 20,  , ease, ease), (1, 1, 4, 3, 21,  , and, and), (1, 1, 4, 3, 22,  , that, that), (1, 1, 4, 3, 23,  , repose, repose), (1, 1, 4, 3, 24,  , to, to), (1, 1, 4, 3, 25,  , say, say), (1, 1, 4, 4, 26,
#  , 'Thus, thus), (1, 1, 4, 4, 27,  , far, far), (1, 1, 4, 4, 28,  , the, the), (1, 1, 4, 4, 29,  , miles, miles), (1, 1, 4, 4, 30,  , are, are), (1, 1, 4, 4, 31,  , measured, measured), (1, 1, 4, 4, 32,  , from, from), (1, 1, 4, 4, 33,  , thy, thy), (1, 1, 4, 4, 34,  , friend!', friend), (1, 2, 5, 5, 1,
#  , The, the), (1, 2, 5, 5, 2,  , beast, beast), (1, 2, 5, 5, 3,  , that, that), (1, 2, 5, 5, 4,  , bears, bears), (1, 2, 5, 5, 5,  , me,, me), (1, 2, 6, 5, 6,  , tired, tired), (1, 2, 6, 5, 7,  , with, with), (1, 2, 6, 5, 8,  , my, my), (1, 2, 6, 5, 9,  , woe,, woe), (1, 2, 7, 6, 10,

# Out:
# Empty DataFrame
# Columns: []
# Index: [(1, 1, 1, 1, , How, how), (1, 1, 1, 2,  , heavy, heavy), (1, 1, 1, 3,  , do, do), (1, 1, 1, 4,  , I, i), (1, 1, 1, 5,  , journey, journey), (1, 1, 1, 6,  , on, on), (1, 1, 1, 7,  , the, the), (1, 1, 1, 8,  , way,, way), (1, 2, 2, 9,
#  , When, when), (1, 2, 2, 10,  , what, what), (1, 2, 2, 11,  , I, i), (1, 2, 2, 12,  , seek,, seek), (1, 3, 2, 13,  , my, my), (1, 3, 2, 14,  , weary, weary), (1, 3, 2, 15,  , travel's, travels), (1, 3, 2, 16,  , end,, end), (1, 4, 3, 17,
#  , Doth, doth), (1, 4, 3, 18,  , teach, teach), (1, 4, 3, 19,  , that, that), (1, 4, 3, 20,  , ease, ease), (1, 4, 3, 21,  , and, and), (1, 4, 3, 22,  , that, that), (1, 4, 3, 23,  , repose, repose), (1, 4, 3, 24,  , to, to), (1, 4, 3, 25,  , say, say), (1, 4, 4, 26,
#  , 'Thus, thus), (1, 4, 4, 27,  , far, far), (1, 4, 4, 28,  , the, the), (1, 4, 4, 29,  , miles, miles), (1, 4, 4, 30,  , are, are), (1, 4, 4, 31,  , measured, measured), (1, 4, 4, 32,  , from, from), (1, 4, 4, 33,  , thy, thy), (1, 4, 4, 34,  , friend!', friend), (2, 5, 5, 1,
#  , The, the), (2, 5, 5, 2,  , beast, beast), (2, 5, 5, 3,  , that, that), (2, 5, 5, 4,  , bears, bears), (2, 5, 5, 5,  , me,, me), (2, 6, 5, 6,  , tired, tired), (2, 6, 5, 7,  , with, with), (2, 6, 5, 8,  , my, my), (2, 6, 5, 9,  , woe,, woe), (2, 7, 6, 10,
#  , Plods, plods), (2, 7, 6, 11,  , dully, dully), (2, 7, 6, 12,  , on,, on), (2, 8, 6, 13,  , to, to), (2, 8, 6, 14,  , bear, bear), (2, 8, 6, 15,  , that, that), (2, 8, 6, 16,  , weight, weight), (2, 8, 6, 17,  , in, in), (2, 8, 6, 18,  , me,, me), (2, 9, 7, 19,
#  , As, as), (2, 9, 7, 20,  , if, if), (2, 9, 7, 21,  , by, by), (2, 9, 7, 22,  , some, some), (2, 9, 7, 23,  , instinct, instinct), (2, 9, 7, 24,  , the, the), (2, 9, 7, 25,  , wretch, wretch), (2, 9, 7, 26,  , did, did), (2, 9, 7, 27,  , know, know), (2, 9, 8, 28,
#  , His, his), (2, 9, 8, 29,  , rider, rider), (2, 9, 8, 30,  , loved, loved), (2, 9, 8, 31,  , not, not), (2, 9, 8, 32,  , speed,, speed), (2, 10, 8, 33,  , being, being), (2, 10, 8, 34,  , made, made), (2, 10, 8, 35,  , from, from), (2, 10, 8, 36,  , thee:, thee), (2, 11, 9, 37,
#  , The, the), (2, 11, 9, 38,  , bloody, bloody), (2, 11, 9, 39,  , spur, spur), (2, 11, 9, 40,  , cannot, cannot), (2, 11, 9, 41,  , provoke, provoke), (2, 11, 9, 42,  , him, him), (2, 11, 9, 43,  , on, on), (2, 11, 10, 44,
#  , That, that), (2, 11, 10, 45,  , sometimes, sometimes), (2, 11, 10, 46,  , anger, anger), (2, 11, 10, 47,  , thrusts, thrusts), (2, 11, 10, 48,  , into, into), (2, 11, 10, 49,  , his, his), (2, 11, 10, 50,  , hide;, hide), (2, 12, 11, 51,
#  , Which, which), (2, 12, 11, 52,  , heavily, heavily), (2, 12, 11, 53,  , he, he), (2, 12, 11, 54,  , answers, answers), (2, 12, 11, 55,  , with, with), (2, 12, 11, 56,  , a, a), (2, 12, 11, 57,  , groan,, groan), (2, 13, 12, 58,
#  , More, more), (2, 13, 12, 59,  , sharp, sharp), (2, 13, 12, 60,  , to, to), (2, 13, 12, 61,  , me, me), (2, 13, 12, 62,  , than, than), (2, 13, 12, 63,  , spurring, spurring), (2, 13, 12, 64,  , to, to), (2, 13, 12, 65,  , his, his), (2, 13, 12, 66,  , side;, side), ...]
#
# [118 rows x 0 columns]

# %%
for dfunit in doc.iter_units(): pass #display(dfunit)
# dfunit

# %%
for dfcombo in doc.iter_combos(): pass
# dfcombo

# %%
dfparses=parse_unit_combos(dfunit)
# dfparses

# %%
doc.parse(index=True,num_proc=8,force=False)
# Out:
# Metrically parsing line units [x8]: 100%|██████████| 14/14 [00:03<00:00,  3.63it/s]
#                                                                                                                                                                                                 *total  ...  word_nsyll
# sent_i sentpart_i unit_i line_i parse_rank is_troch parse_i parse      combo_i slot_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress syll_weight          ...
# 1      1          1      1      1          0        1       wSwSwSwSwS 2       1      1                How      how      1          haʊ       1      how      haʊ      U           H               0.0  ...           1
#                                                                                2      2                heavy    heavy    1          'hɛ.viː   1      hea      'hɛ      P           L               0.0  ...           2
#                                                                                3      2                heavy    heavy    1          'hɛ.viː   2      vy       viː      U           L               0.0  ...           2
#                                                                                4      3                do       do       1          'duː      1      do       'duː     P           L               0.0  ...           1
#                                                                                5      4                I        i        2          aɪ        1      i        aɪ       U           H               0.0  ...           1
# ...                                                                                                                                                                                                ...  ...         ...
# 2      15         14     14     1          0        1       wSwSwSwSwS 1       6      81               and      and      1          ænd       1      and      ænd      U           H               1.0  ...           1
#                                                                                7      82               my       my       1          maɪ       1      my       maɪ      U           H               0.0  ...           1
#                                                                                8      83               joy      joy      1          'ʤɔɪ      1      joy      'ʤɔɪ     P           H               0.0  ...           1
#                                                                                9      84               behind.  behind   1          bɪ.'haɪnd 1      be       bɪ       U           L               0.0  ...           2
#                                                                                10     84               behind.  behind   1          bɪ.'haɪnd 2      hind     'haɪnd   P           H               0.0  ...           2
#
# [292 rows x 35 columns]

# %%
# for dfunit in doc.parse_iter(incl_data=False):
#     display(dfunit)
