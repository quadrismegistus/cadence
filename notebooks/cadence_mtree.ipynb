# %%
import sys; sys.path.insert(0,'/Users/ryan/github/prosodic/')
import sys; sys.path.insert(0,'/Users/ryan/github/cadence/')
from cadence.imports import *

# %%
# t=Text(joyce_path)
# s='''For so have I seen a lark rising from his bed of grass,
# soaring upwards and singing as he rises
# and hopes to get to Heaven
# and climb above the clouds.'''
# s='The number of the dead long exceeds all that shall live again.'
s='Oblivion is not to be hired: the greater part must be content to be as though they had not been, to be found in the Register of God, not in the record of man.'
# s='I profess to your highness, in the integrity of my heart, that what I am going to say is literally true this minute I am writing.'
# s='Prayer | is the peace | of our spirit, | the stillness | of our thoughts, | the evenness | of recollection, | the seat | of meditation, | the rest | of our cares | and the calm | of our tempest.'
# s='He brought light out of darkness, not out of a lesser light; He can bring thy summer out of winter, though thou have no spring'
# s='For so have I seen a lark rising from his bed of grass.'
# s='Into the light of the long, winding forest we go.'
# s='In vain do individuals hope for Immortality.'
s='The air there, air supposed to possess the singular property of restoring the whiteness of ivory, was pure and thin.'
s='Whatever is, is right.'
s="""
And, spite of pride, in erring reason's spite,
One truth is clear, Whatever is, is right.
"""

t=Text(s, force=True)
# tree

# %%
sent = t.sent(1)
sent.mtree()
# Out:
# [cadence] A word unknown to the pronunciation dictionary ("erring") cannot be syllabified because espeak text-to-speech software is not installed. It is highly recommend you install this software.
#
# To install:
#
#     * On Linux, type into the terminal:
#         apt-get install espeak
#
#     * On Mac:
#         (1) Install homebrew if not already installed. Paste into Terminal app:
#             /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#
#         (2) Type into the Terminal app:
#             brew install espeak
#
#     * On Windows:
#         Download and install from http://espeak.sourceforge.net/download.html.
# CadenceMetricalTree('ROOT/0', [CadenceMetricalTree('S/0', [CadenceMetricalTree('S/0', [CadenceMetricalTree('CC/0', ['And']), CadenceMetricalTree(',/0', [',']), CadenceMetricalTree('NP/0', [CadenceMetricalTree('NP/0', [CadenceMetricalTree('NN/0', ['spite'])]), CadenceMetricalTree('PP/0', [CadenceMetricalTree('IN/0', ['of']), CadenceMetricalTree('NP/0', [CadenceMetricalTree('NN/0', ['pride'])])])]), CadenceMetricalTree(',/0', [',']), CadenceMetricalTree('PP/0', [CadenceMetricalTree('IN/0', ['in']), CadenceMetricalTree('S/0', [CadenceMetricalTree('VP/0', [CadenceMetricalTree('VBG/0', ['erring']), CadenceMetricalTree('S/0', [CadenceMetricalTree('NP/0', [CadenceMetricalTree('NNS/0', ["reason's"])]), CadenceMetricalTree('VP/0', [CadenceMetricalTree('NN/0', ['spite'])])])])])]), CadenceMetricalTree(',/0', [',']), CadenceMetricalTree('NP/0', [CadenceMetricalTree('CD/0', ['One']), CadenceMetricalTree('NN/0', ['truth'])]), CadenceMetricalTree('VP/0', [CadenceMetricalTree('VBZ/0', ['is']), CadenceMetricalTree('ADJP/0', [CadenceMetricalTree('JJ/0', ['clear'])]), CadenceMetricalTree('PRN/0', [CadenceMetricalTree(',/0', [',']), CadenceMetricalTree('WHNP/0', [CadenceMetricalTree('WDT/0', ['Whatever'])]), CadenceMetricalTree('S/0', [CadenceMetricalTree('VP/0', [CadenceMetricalTree('VBZ/0', ['is'])])]), CadenceMetricalTree(',/0', [','])])])]), CadenceMetricalTree('VP/0', [CadenceMetricalTree('VBZ/0', ['is']), CadenceMetricalTree('ADJP/0', [CadenceMetricalTree('JJ/0', ['right'])])]), CadenceMetricalTree('./0', ['.'])])])

# %%
sent.mtree().get_stats()
# Out:
#     word_i  word_str  prom_lstress  ...  prom_tstress  prom_pstrength  mtree_ishead
# 0        1       And           0.0  ...           0.4             NaN           NaN
# 1        2         ,           NaN  ...           NaN             NaN           NaN
# 2        3     spite           1.0  ...           0.4             1.0           NaN
# 3        4        of           0.0  ...           0.2             0.0           NaN
# 4        5     pride           1.0  ...           0.6             1.0           NaN
# 5        6         ,           NaN  ...           NaN             NaN           NaN
# 6        7        in           0.0  ...           0.2             NaN           NaN
# 7        8    erring           1.0  ...           0.4             0.0           NaN
# 8        9  reason's           1.0  ...           0.4             1.0           NaN
# 9       10     spite           1.0  ...           0.6             NaN           NaN
# 10      11         ,           NaN  ...           NaN             NaN           NaN
# 11      12       One           0.0  ...           0.2             0.0           0.0
# 12      13     truth           1.0  ...           0.6             1.0           1.0
# 13      14        is           0.0  ...           0.4             0.0           NaN
# 14      15     clear           1.0  ...           0.6             1.0           NaN
# 15      16         ,           NaN  ...           NaN             NaN           0.0
# 16      17  Whatever           1.0  ...           0.8             1.0           NaN
# 17      18        is           0.0  ...           0.0             0.0           NaN
# 18      19         ,           NaN  ...           NaN             NaN           1.0
# 19      20        is           0.0  ...           0.6             0.0           NaN
# 20      21     right           1.0  ...           1.0             1.0           NaN
# 21      22         .           NaN  ...           NaN             NaN           1.0
#
# [22 rows x 7 columns]

# %%
sent.grid()
# Out:
# <ggplot: (731510766)>
