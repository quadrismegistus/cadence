# %%
import sys; sys.path.insert(0,'..')
from cadence.imports import *

# %%
s="""Whatever is,
is right."""

# %%
t=Text(s,force=True)

# %%
t.words()
# Out:
#                                                           word_ispunc
# para_i sent_i sentpart_i line_i word_i word_str word_tok
# 1      1      1          1      1      Whatever whatever            0
#                                 2       is      is                  0
#                                 3      ,                            1
#               2          2      4      \nis     is                  0
#                                 5       right   right               0
#                                 6      .                            1

# %%
t.sylls()
# Out:
#                                                                                                                                   prom_strength  ...  word_nsyll
# para_i sent_i sentpart_i line_i word_i word_str word_tok word_ipa_i word_ipa    syll_i syll_str syll_ipa syll_stress syll_weight                 ...
# 1      1      1          1      1      Whatever whatever 1          `wə.'tɛ.vɛː 1      wha      `wə      S           L                      0.0  ...           3
#                                                                                 2      te       'tɛ      P           L                      1.0  ...           3
#                                                                                 3      ver      vɛː      U           L                      0.0  ...           3
#                                 2       is      is       1          'ɪz         1      is       'ɪz      P           H                      1.0  ...           1
#                                                          2          ɪz          1      is       ɪz       U           H                      0.0  ...           1
#               2          2      4      \nis     is       1          'ɪz         1      is       'ɪz      P           H                      1.0  ...           1
#                                                          2          ɪz          1      is       ɪz       U           H                      0.0  ...           1
#                                 5       right   right    1          'raɪt       1      right    'raɪt    P           H                      NaN  ...           1
#
# [8 rows x 6 columns]

# %%
t.syntax()
# Out:
#                                dep_head dep_type  ... pos_xpos word_depth
# para_i sent_i word_i word_str                     ...
# 1      1      1      Whatever         5    nsubj  ...      WDT          5
#               2      is               5      cop  ...      VBZ          6
#               3      ,                5    punct  ...        ,          3
#               4      is               5      cop  ...      VBZ          4
#               5      right            0     root  ...       JJ          5
#               6      .                5    punct  ...        .          3
#
# [6 rows x 12 columns]

# %%
t.sent(1).mtree()
# Out:
# CadenceMetricalTree('ROOT/0', [CadenceMetricalTree('S/0', [CadenceMetricalTree('SBAR/0', [CadenceMetricalTree('WHNP/0', [CadenceMetricalTree('WDT/0', ['Whatever'])]), CadenceMetricalTree('S/0', [CadenceMetricalTree('VP/0', [CadenceMetricalTree('VBZ/0', ['is'])])])]), CadenceMetricalTree(',/0', [',']), CadenceMetricalTree('VP/0', [CadenceMetricalTree('VBZ/0', ['is']), CadenceMetricalTree('ADJP/0', [CadenceMetricalTree('JJ/0', ['right'])])]), CadenceMetricalTree('./0', ['.'])])])

# %%
t.mtrees()
# Out:
#                                mtree_ishead  ...  prom_tstress
# para_i sent_i word_i word_str                ...
# 1      1      1      Whatever           NaN  ...           0.8
#               2      is                 NaN  ...           0.0
#               3      ,                  0.0  ...           NaN
#               4      is                 NaN  ...           0.6
#               5      right              NaN  ...           1.0
#               6      .                  1.0  ...           NaN
#
# [6 rows x 5 columns]

# %%
for dfunit in t.para(1).iter_units():
    display(dfunit)
# Out:
#    sent_i  sentpart_i  line_i  word_i  ... pos_person pos_upos  pos_degree unit_i
# 0       1           1       1       1  ...                PRON                  1
# 1       1           1       1       1  ...                PRON                  1
# 2       1           1       1       1  ...                PRON                  1
# 3       1           1       1       2  ...          3      AUX                  1
# 4       1           1       1       2  ...          3      AUX                  1
# 5       1           1       1       3  ...               PUNCT                  1
#
# [6 rows x 37 columns]
#    sent_i  sentpart_i  line_i  word_i  ... pos_person pos_upos  pos_degree unit_i
# 6       1           2       2       4  ...          3      AUX                  2
# 7       1           2       2       4  ...          3      AUX                  2
# 8       1           2       2       5  ...                 ADJ         Pos      2
# 9       1           2       2       6  ...               PUNCT                  2
#
# [4 rows x 37 columns]

# %%
next(iter_combos(dfunit))
# Out:
#         sent_i  sentpart_i  unit_i  ...  pos_upos  pos_degree combo_i
# slot_i                              ...
# 1            1           2       2  ...       AUX                   1
# 2            1           2       2  ...       ADJ         Pos       1
#
# [2 rows x 38 columns]

# %%
t.words()
# Out:
#                                                           word_ispunc
# para_i sent_i sentpart_i line_i word_i word_str word_tok
# 1      1      1          1      1      Whatever whatever            0
#                                 2       is      is                  0
#                                 3      ,                            1
#               2          2      4      \nis     is                  0
#                                 5       right   right               0
#                                 6      .                            1

# %%
t.data()
# Out:
#                                                                                                                                   dep_head  ... word_nsyll
# para_i sent_i sentpart_i line_i word_i word_str word_tok word_ipa_i word_ipa    syll_i syll_str syll_ipa syll_stress syll_weight            ...
# 1      1      1          1      1      Whatever whatever 1.0        `wə.'tɛ.vɛː 1.0    wha      `wə      S           L                   5  ...        3.0
#                                                                                 2.0    te       'tɛ      P           L                   5  ...        3.0
#                                                                                 3.0    ver      vɛː      U           L                   5  ...        3.0
#                                 2       is      is       1.0        'ɪz         1.0    is       'ɪz      P           H                   5  ...        1.0
#                                                          2.0        ɪz          1.0    is       ɪz       U           H                   5  ...        1.0
#                                 3      ,                 NaN        NaN         NaN    NaN      NaN      NaN         NaN                 5  ...        NaN
#               2          2      4      \nis     is       1.0        'ɪz         1.0    is       'ɪz      P           H                   5  ...        1.0
#                                                          2.0        ɪz          1.0    is       ɪz       U           H                   5  ...        1.0
#                                 5       right   right    1.0        'raɪt       1.0    right    'raɪt    P           H                   0  ...        1.0
#                                 6      .                 NaN        NaN         NaN    NaN      NaN      NaN         NaN                 5  ...        NaN
#
# [10 rows x 23 columns]

# %%
t.parse(incl_data=True)
# Out:
# Metrically parsing line units [x1]: 100%|██████████| 2/2 [00:00<00:00, 10.17it/s]
#                                                                                                                                                                                           *total  ...  word_nsyll
# para_i sent_i sentpart_i unit_i line_i parse_rank is_troch parse_i parse combo_i slot_i word_i word_str word_tok word_ipa_i word_ipa    syll_i syll_str syll_ipa syll_stress syll_weight          ...
# 1      1      1          1      1      1          0        1       wSwS  1       1      1      Whatever whatever 1          `wə.'tɛ.vɛː 1      wha      `wə      S           L               0.5  ...         3.0
#                                                                                  2      1      Whatever whatever 1          `wə.'tɛ.vɛː 2      te       'tɛ      P           L               0.0  ...         3.0
#                                                                                  3      1      Whatever whatever 1          `wə.'tɛ.vɛː 3      ver      vɛː      U           L               0.0  ...         3.0
#                                                                                  4      2       is      is       1          'ɪz         1      is       'ɪz      P           H               0.0  ...         1.0
#                                        2          0        2       SSwS  1       1      1      Whatever whatever 1          `wə.'tɛ.vɛː 1      wha      `wə      S           L               0.5  ...         3.0
#                                                                                  2      1      Whatever whatever 1          `wə.'tɛ.vɛː 2      te       'tɛ      P           L               0.0  ...         3.0
#                                                                                  3      1      Whatever whatever 1          `wə.'tɛ.vɛː 3      ver      vɛː      U           L               0.0  ...         3.0
#                                                                                  4      2       is      is       1          'ɪz         1      is       'ɪz      P           H               0.0  ...         1.0
#
# [8 rows x 31 columns]
