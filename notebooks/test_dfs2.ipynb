# %%
import sys; sys.path.append('..')
import prosodic2 as p
from tqdm import tqdm
import pandas as pd
# %load_ext line_profiler

# %%
pd.options.display.max_columns=None

# %%
txt="""Into the forest we go
"""

# %%
def go():
    t=p.Text(txt)
    return pd.concat(t.parse_meter(keep_best=5))

# %%
go()
# Out:
# Tokenizing and syllabifying [x1]: 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]
# Parsing lines [x1]:   0%|          | 0/1 [00:00<?, ?it/s]
# ## df combos
#          stanza_i  line_i  word_i  word_ipa_i  syll_i word_str   word_ipa  \
# combo_i
# 0               0       0       0           1       0     Into    'ɪn.tuː
# 0               0       0       0           1       1     Into    'ɪn.tuː
# 0               0       0       1           0       0      the         ðə
# 0               0       0       2           0       0   forest  'fɔː.rəst
# 0               0       0       2           0       1   forest  'fɔː.rəst
# 0               0       0       3           0       0       we        wiː
# 0               0       0       4           0       0       go       'goʊ
# 1               0       0       0           0       0     Into    ɪn.'tuː
# 1               0       0       0           0       1     Into    ɪn.'tuː
# 1               0       0       1           0       0      the         ðə
# 1               0       0       2           0       0   forest  'fɔː.rəst
# 1               0       0       2           0       1   forest  'fɔː.rəst
# 1               0       0       3           0       0       we        wiː
# 1               0       0       4           0       0       go       'goʊ
# 2               0       0       0           2       0     Into      ɪn.tʌ
# 2               0       0       0           2       1     Into      ɪn.tʌ
# 2               0       0       1           0       0      the         ðə
# 2               0       0       2           0       0   forest  'fɔː.rəst
# 2               0       0       2           0       1   forest  'fɔː.rəst
# 2               0       0       3           0       0       we        wiː
# 2               0       0       4           0       0       go       'goʊ
#
#         syll_ipa syll_str  prom_stress  prom_strength  is_stressed  \
# combo_i
# 0            'ɪn       In          1.0            1.0            1
# 0            tuː       to          0.0            0.0            0
# 0             ðə      the          0.0            NaN            0
# 0           'fɔː      for          1.0            1.0            1
# 0           rəst      est          0.0            0.0            0
# 0            wiː       we          0.0            NaN            0
# 0           'goʊ       go          1.0            NaN            1
# 1             ɪn       In          0.0            0.0            0
# 1           'tuː       to          1.0            1.0            1
# 1             ðə      the          0.0            NaN            0
# 1           'fɔː      for          1.0            1.0            1
# 1           rəst      est          0.0            0.0            0
# 1            wiː       we          0.0            NaN            0
# 1           'goʊ       go          1.0            NaN            1
# 2             ɪn       In          0.0            NaN            0
# 2             tʌ       to          0.0            NaN            0
# 2             ðə      the          0.0            NaN            0
# 2           'fɔː      for          1.0            1.0            1
# 2           rəst      est          0.0            0.0            0
# 2            wiː       we          0.0            NaN            0
# 2           'goʊ       go          1.0            NaN            1
#
#          is_unstressed  is_peak  is_trough     window_key
# combo_i
# 0                    0        1          0          __'ɪn
# 0                    1        0          1       _'ɪn_tuː
# 0                    1        0          0     'ɪn_tuː_ðə
# 0                    0        1          0    tuː_ðə_'fɔː
# 0                    1        0          1   ðə_'fɔː_rəst
# 0                    1        0          0  'fɔː_rəst_wiː
# 0                    0        0          0  rəst_wiː_'goʊ
# 1                    1        0          1           __ɪn
# 1                    0        1          0       _ɪn_'tuː
# 1                    1        0          0     ɪn_'tuː_ðə
# 1                    0        1          0   'tuː_ðə_'fɔː
# 1                    1        0          1   ðə_'fɔː_rəst
# 1                    1        0          0  'fɔː_rəst_wiː
# 1                    0        0          0  rəst_wiː_'goʊ
# 2                    1        0          0           __ɪn
# 2                    1        0          0         _ɪn_tʌ
# 2                    1        0          0       ɪn_tʌ_ðə
# 2                    0        1          0     tʌ_ðə_'fɔː
# 2                    1        0          1   ðə_'fɔː_rəst
# 2                    1        0          0  'fɔː_rəst_wiː
# 2                    0        0          0  rəst_wiː_'goʊ
# ## df_uniq_windows
#                              stanza_i  line_i  word_ipa_i word_str   word_ipa  \
# window_key    word_i syll_i
# 'fɔː_rəst_wiː 3      0              0       0           0       we        wiː
# 'ɪn_tuː_ðə    1      0              0       0           0      the         ðə
# _'ɪn_tuː      0      1              0       0           1     Into    'ɪn.tuː
# __'ɪn         0      0              0       0           1     Into    'ɪn.tuː
# rəst_wiː_'goʊ 4      0              0       0           0       go       'goʊ
# tuː_ðə_'fɔː   2      0              0       0           0   forest  'fɔː.rəst
# ðə_'fɔː_rəst  2      1              0       0           0   forest  'fɔː.rəst
# 'fɔː_rəst_wiː 3      0              0       0           0       we        wiː
# 'tuː_ðə_'fɔː  2      0              0       0           0   forest  'fɔː.rəst
# __ɪn          0      0              0       0           0     Into    ɪn.'tuː
# _ɪn_'tuː      0      1              0       0           0     Into    ɪn.'tuː
# rəst_wiː_'goʊ 4      0              0       0           0       go       'goʊ
# ðə_'fɔː_rəst  2      1              0       0           0   forest  'fɔː.rəst
# ɪn_'tuː_ðə    1      0              0       0           0      the         ðə
# 'fɔː_rəst_wiː 3      0              0       0           0       we        wiː
# __ɪn          0      0              0       0           2     Into      ɪn.tʌ
# _ɪn_tʌ        0      1              0       0           2     Into      ɪn.tʌ
# rəst_wiː_'goʊ 4      0              0       0           0       go       'goʊ
# tʌ_ðə_'fɔː    2      0              0       0           0   forest  'fɔː.rəst
# ðə_'fɔː_rəst  2      1              0       0           0   forest  'fɔː.rəst
# ɪn_tʌ_ðə      1      0              0       0           0      the         ðə
#
#                             syll_ipa syll_str  prom_stress  prom_strength  \
# window_key    word_i syll_i
# 'fɔː_rəst_wiː 3      0           wiː       we          0.0            NaN
# 'ɪn_tuː_ðə    1      0            ðə      the          0.0            NaN
# _'ɪn_tuː      0      1           tuː       to          0.0            0.0
# __'ɪn         0      0           'ɪn       In          1.0            1.0
# rəst_wiː_'goʊ 4      0          'goʊ       go          1.0            NaN
# tuː_ðə_'fɔː   2      0          'fɔː      for          1.0            1.0
# ðə_'fɔː_rəst  2      1          rəst      est          0.0            0.0
# 'fɔː_rəst_wiː 3      0           wiː       we          0.0            NaN
# 'tuː_ðə_'fɔː  2      0          'fɔː      for          1.0            1.0
# __ɪn          0      0            ɪn       In          0.0            0.0
# _ɪn_'tuː      0      1          'tuː       to          1.0            1.0
# rəst_wiː_'goʊ 4      0          'goʊ       go          1.0            NaN
# ðə_'fɔː_rəst  2      1          rəst      est          0.0            0.0
# ɪn_'tuː_ðə    1      0            ðə      the          0.0            NaN
# 'fɔː_rəst_wiː 3      0           wiː       we          0.0            NaN
# __ɪn          0      0            ɪn       In          0.0            NaN
# _ɪn_tʌ        0      1            tʌ       to          0.0            NaN
# rəst_wiː_'goʊ 4      0          'goʊ       go          1.0            NaN
# tʌ_ðə_'fɔː    2      0          'fɔː      for          1.0            1.0
# ðə_'fɔː_rəst  2      1          rəst      est          0.0            0.0
# ɪn_tʌ_ðə      1      0            ðə      the          0.0            NaN
#
#                              is_stressed  is_unstressed  is_peak  is_trough
# window_key    word_i syll_i
# 'fɔː_rəst_wiː 3      0                 0              1        0          0
# 'ɪn_tuː_ðə    1      0                 0              1        0          0
# _'ɪn_tuː      0      1                 0              1        0          1
# __'ɪn         0      0                 1              0        1          0
# rəst_wiː_'goʊ 4      0                 1              0        0          0
# tuː_ðə_'fɔː   2      0                 1              0        1          0
# ðə_'fɔː_rəst  2      1                 0              1        0          1
# 'fɔː_rəst_wiː 3      0                 0              1        0          0
# 'tuː_ðə_'fɔː  2      0                 1              0        1          0
# __ɪn          0      0                 0              1        0          1
# _ɪn_'tuː      0      1                 1              0        1          0
# rəst_wiː_'goʊ 4      0                 1              0        0          0
# ðə_'fɔː_rəst  2      1                 0              1        0          1
# ɪn_'tuː_ðə    1      0                 0              1        0          0
# 'fɔː_rəst_wiː 3      0                 0              1        0          0
# __ɪn          0      0                 0              1        0          0
# _ɪn_tʌ        0      1                 0              1        0          0
# rəst_wiː_'goʊ 4      0                 1              0        0          0
# tʌ_ðə_'fɔː    2      0                 1              0        1          0
# ðə_'fɔː_rəst  2      1                 0              1        0          1
# ɪn_tʌ_ðə      1      0                 0              1        0          0
#                stanza_i  line_i  word_ipa_i word_str word_ipa syll_ipa  \
# word_i syll_i
# 0      0              0       0           1     Into  'ɪn.tuː      'ɪn
#
#               syll_str  prom_stress  prom_strength  is_stressed  \
# word_i syll_i
# 0      0            In          1.0            1.0            1
#
#                is_unstressed  is_peak  is_trough
# word_i syll_i
# 0      0                   0        1          0
# ## df metrical poss
#                           stanza_i  line_i  word_ipa_i word_str   word_ipa  \
# window_key    mpos_parse
# 'fɔː_rəst_wiː wws                0       0           0       we        wiː
#               wws                0       0           0       we        wiː
#               wws                0       0           0       we        wiː
#               wws                0       0           0       we        wiː
#               wws                0       0           0       we        wiː
# ...                            ...     ...         ...      ...        ...
# ðə_'fɔː_rəst  wws                0       0           0   forest  'fɔː.rəst
# ɪn_'tuː_ðə    w                  0       0           0      the         ðə
#               w                  0       0           0      the         ðə
# ɪn_tʌ_ðə      w                  0       0           0      the         ðə
#               w                  0       0           0      the         ðə
#
#                          syll_ipa syll_str  prom_stress  prom_strength  \
# window_key    mpos_parse
# 'fɔː_rəst_wiː wws             wiː       we          0.0            NaN
#               wws             wiː       we          0.0            NaN
#               wws             wiː       we          0.0            NaN
#               wws             wiː       we          0.0            NaN
#               wws             wiː       we          0.0            NaN
# ...                           ...      ...          ...            ...
# ðə_'fɔː_rəst  wws            rəst      est          0.0            0.0
# ɪn_'tuː_ðə    w                ðə      the          0.0            NaN
#               w                ðə      the          0.0            NaN
# ɪn_tʌ_ðə      w                ðə      the          0.0            NaN
#               w                ðə      the          0.0            NaN
#
#                           is_stressed  is_unstressed  is_peak  is_trough  \
# window_key    mpos_parse
# 'fɔː_rəst_wiː wws                   0              1        0          0
#               wws                   0              1        0          0
#               wws                   0              1        0          0
#               wws                   0              1        0          0
#               wws                   0              1        0          0
# ...                               ...            ...      ...        ...
# ðə_'fɔː_rəst  wws                   0              1        0          1
# ɪn_'tuː_ðə    w                     0              1        0          0
#               w                     0              1        0          0
# ɪn_tʌ_ðə      w                     0              1        0          0
#               w                     0              1        0          0
#
#                          syll_parse  is_w  is_s  mpos_parse_i
# window_key    mpos_parse
# 'fɔː_rəst_wiː wws                 w     1     0             5
#               wws                 w     1     0             5
#               wws                 s     0     1             5
#               wws                 w     1     0             5
#               wws                 w     1     0             5
# ...                             ...   ...   ...           ...
# ðə_'fɔː_rəst  wws                 s     0     1             5
# ɪn_'tuː_ðə    w                   w     1     0             1
#               w                   w     1     0             1
# ɪn_tʌ_ðə      w                   w     1     0             1
#               w                   w     1     0             1
#
# [82 rows x 17 columns]
# Parsing lines [x1]:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e219d4ec9c81> in <module>
# ----> 1 go()
#
# <ipython-input-4-fc4a57ca9774> in go()
#       1 def go():
#       2     t=p.Text(txt)
# ----> 3     return pd.concat(t.parse_meter(keep_best=5))
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     326             objs = [objs[k] for k in keys]
#     327         else:
# --> 328             objs = list(objs)
#     329
#     330         if len(objs) == 0:
#
# ~/github/prosodic2/prosodic2/prosodic2.py in parse_meter(self, df, **y)
#      32             if df is None: df = self.parse_phon(**y)
#      33             l=[]
# ---> 34             for group in parse_lines(df,**y):
#      35                 yield group
#      36                 l+=[group]
#
# ~/github/prosodic2/prosodic2/parsers/metrics.py in parse_lines(df_phon, num_proc, keep_best, **y)
#       9         progress=True,
#      10         desc='Parsing lines',
# ---> 11         **y
#      12     )
#      13
#
# ~/github/prosodic2/prosodic2/tools/tools.py in pmap_groups(func, df_grouped, use_cache, num_proc, iter, **attrs)
#     125                 **attrs
#     126 	):
# --> 127                 yield from group_iter
#     128
#     129
#
# ~/github/prosodic2/prosodic2/tools/tools.py in do_pmap_group(obj, *args, **kwargs)
#      85         outgen=func(group_df,*args,**kwargs)
#      86         # outdf=pd.concat(out) if isinstance(out, types.GeneratorType) else out
# ---> 87         for outdf in outgen:
#      88                 for x,y in zip(group_key,group_name): outdf[x]=y
#      89                 yield outdf
#
# ~/github/prosodic2/prosodic2/parsers/metrics.py in parse_line(line_df, num_proc, window_len, by_line, keep_best, addback_str, **y)
#     124     ikey=['window_key']
#     125     cols=ikey + [c for c in df_combos.columns if not c in set(df_windows.columns)]
# --> 126     df_all = df_combos[cols].merge(df_windows,on=ikey,how='outer')
#     127     df_all = df_all.sort_values(['combo_i','word_i','syll_i']).drop_duplicates()
#     128     printm('### df all')
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7957             copy=copy,
#    7958             indicator=indicator,
# -> 7959             validate=validate,
#    7960         )
#    7961
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     650             self.right_join_keys,
#     651             self.join_names,
# --> 652         ) = self._get_merge_keys()
#     653
#     654         # validate the merge keys dtypes. We may need to coerce
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1003                     if not is_rkey(rk):
#    1004                         if rk is not None:
# -> 1005                             right_keys.append(right._get_label_or_level_values(rk))
#    1006                         else:
#    1007                             # work-around for merge_asof(right_index=True)
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1556
#    1557         if self._is_label_reference(key, axis=axis):
# -> 1558             self._check_label_or_level_ambiguity(key, axis=axis)
#    1559             values = self.xs(key, axis=other_axes[0])._values
#    1560         elif self._is_level_reference(key, axis=axis):
#
# ~/github/lltk/venv/lib/python3.7/site-packages/pandas/core/generic.py in _check_label_or_level_ambiguity(self, key, axis)
#    1516                 f"{label_article} {label_type} label, which is ambiguous."
#    1517             )
# -> 1518             raise ValueError(msg)
#    1519
#    1520     def _get_label_or_level_values(self, key: str, axis: int = 0) -> np.ndarray:
#
# ValueError: 'window_key' is both an index level and a column label, which is ambiguous.

# %%
# %lprun -T lprun2 -s -f go -m prosodic2 go()

# %%
# !head -n 50 lprun2
