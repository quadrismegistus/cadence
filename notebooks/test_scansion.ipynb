# %%
# Test scansion

# %%
import sys; sys.path.append('..')
from cadence.imports import *
# %load_ext line_profiler

# %%
txt="""
But wherefore do not you a mightier way
Make war upon this bloody tyrant, Time?
And fortify your self in your decay
With means more blessed than my barren rhyme?
Now stand you on the top of happy hours,
And many maiden gardens, yet unset,
With virtuous wish would bear you living flowers,
Much liker than your painted counterfeit:
So should the lines of life that life repair,
Which this, Time's pencil, or my pupil pen,
Neither in inward worth nor outward fair,
Can make you live your self in eyes of men.
   To give away yourself, keeps yourself still,
   And you must live, drawn by your own sweet skill.
"""

# %%
# %%timeit
parse(txt,verse=True,verbose=False)
# Out:
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.69it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.85it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.86it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.80it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.76it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.69it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.63it/s]
# Metrically parsing lines [x1]: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:02<00:00,  6.64it/s]
# 2.42 s ± 31.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %lprun -f scan_iter scan(txt)
# Out:
# Iterating over line scansions [x1]: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 46.60it/s]
# Timer unit: 1e-06 s
#
# Total time: 0.437389 s
# File: ../cadence/parsers/txtparsing.py
# Function: scan_iter at line 105
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    105                                           def scan_iter(txt_or_fn,lang=DEFAULT_LANG,
#    106                                                   progress=True,
#    107                                                   incl_alt=INCL_ALT,
#    108                                                   num_proc=DEFAULT_NUM_PROC,
#    109                                                   linebreaks=True,
#    110                                                   phrasebreaks=True,
#    111                                                   verse=None,
#    112                                                   prose=None,
#    113                                                   desc='Iterating over line scansions',
#    114                                                   **kwargs):
#    115         1         22.0     22.0      0.0      full_txt=to_txt(txt_or_fn)
#    116         1          1.0      1.0      0.0      if not full_txt: return
#    117
#    118         1          1.0      1.0      0.0      if verse:
#    119                                                   linebreaks=True
#    120                                                   phrasebreaks=False
#    121         1          0.0      0.0      0.0      elif prose:
#    122                                                   linebreaks=False
#    123                                                   phrasebreaks=True
#    124
#    125         1        601.0    601.0      0.1      df=pd.DataFrame()
#    126         1          1.0      1.0      0.0      dfl=[]
#    127         1          1.0      1.0      0.0      to_lines_now = to_lines_str if linebreaks else to_sents_str
#    128         1          1.0      1.0      0.0      kwargs['lang']=lang
#    129         1          1.0      1.0      0.0      kwargs['incl_alt']=incl_alt
#    130
#    131         1          0.0      0.0      0.0      def getkey(linepart_txt):
#    132                                                   return hashstr(str([
#    133                                                       linepart_txt,
#    134                                                       sorted(kwargs.items())
#    135                                                   ]))[:12]
#    136
#    137         2       1400.0    700.0      0.3      objs=[
#    138                                                   (
#    139                                                       stanza_i,stanza_txt,
#    140                                                       line_i,line_txt,
#    141                                                       linepart_i,linepart_txt,
#    142                                                       getkey(linepart_txt)
#    143                                                   )
#    144         1          4.0      4.0      0.0          for stanza_i,stanza_txt in enumerate(to_stanzas(full_txt))
#    145                                                   for line_i,line_txt in enumerate(to_lines_now(stanza_txt))
#    146                                                   for linepart_i,linepart_txt in enumerate(
#    147                                                       to_lineparts(line_txt) if phrasebreaks else [line_txt]
#    148                                                   )
#    149                                               ]
#    150
#    151                                           #     with get_db('lines','r') as db:
#    152                                           #         objs_done=[]
#    153                                           #         objs_todo=[]
#    154                                           #         for obj in objs:
#    155                                           #             key=obj[-1]
#    156                                           #             if key in db:
#    157                                           #                 objs_done[key]=db[key]
#    158
#    159
#    160
#    161
#    162         2          2.0      1.0      0.0      iterr=pmap_iter(
#    163         1          1.0      1.0      0.0          do_scan_iter,
#    164         1          0.0      0.0      0.0          objs,
#    165         1          1.0      1.0      0.0          kwargs=kwargs,
#    166         1          1.0      1.0      0.0          num_proc=num_proc,
#    167         1          1.0      1.0      0.0          desc=desc,
#    168         1          0.0      0.0      0.0          progress=progress
#    169                                               )
#    170
#    171                                           #     dfl=[]
#    172         1          1.0      1.0      0.0      i=0#
#    173                                               #with get_db('lines','c') as db:
#    174         1          0.0      0.0      0.0      lpi=None
#    175         1          1.0      1.0      0.0      ol=[]
#    176        21     308751.0  14702.4     70.6      for dfi,df in enumerate(iterr):
#    177        20         28.0      1.4      0.0          (stanza_i,stanza_txt,line_i,line_txt,linepart_i,linepart_txt,key) = objs[dfi]
#    178        20         13.0      0.7      0.0          lpinow=(stanza_i,line_i)
#    179        20         17.0      0.8      0.0          if lpi is not None and lpi!=lpinow and ol:
#    180        13      36090.0   2776.2      8.3              yield pd.concat(ol)
#    181        13         63.0      4.8      0.0              ol=[]
#    182
#    183        20      10023.0    501.1      2.3          df['stanza_i']=stanza_i+1
#    184        20      10247.0    512.4      2.3          df['line_i']=line_i+1
#    185        20      10278.0    513.9      2.3          df['line_str']=line_txt
#    186        20      10377.0    518.9      2.4          df['linepart_i']=linepart_i+1
#    187        20       9979.0    498.9      2.3          df['linepart_str']=linepart_txt
#    188                                                   # print(df.is_syll.value_counts())
#    189                                                   # df['linepart_num_syll']=len(df.query('word_ipa_i==1'))#& is_syll==1'))
#    190        20      35348.0   1767.4      8.1          df['linepart_num_syll']=len(df[df.word_ipa_i==1])
#    191                                                   # if 'is_syll' in set(df.columns):
#    192                                                   #     uniqdf=df[df.is_syll==1].drop_duplicates(['word_i','syll_i'])
#    193                                                   #     df['linepart_num_syll']=len(uniqdf)
#    194
#    195                                                   #display(df)
#    196                                                   #stop
#    197
#    198        20         33.0      1.6      0.0          ol+=[df]
#    199        20         35.0      1.8      0.0          lpi=lpinow
#    200         1       4066.0   4066.0      0.9      if ol: yield pd.concat(ol)

# %%
scan(txt)
# Out:
# Iterating over line scansions [x1]: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 100.54it/s]
#                                                                                                                                                                                                             is_funcword  ...  prom_weight
# stanza_i line_i line_str                                          linepart_i linepart_str                            word_i word_str  word_ipa_i word_ipa syll_i syll_str syll_ipa syll_stress syll_weight               ...
# 1        1      But wherefore do not you a mightier way           1          But wherefore do not you a mightier way 1      But       1          bət      1      But      bət      U           L                      1  ...          NaN
#                                                                                                                      2      wherefore 1          'wəː.fɔː 1      where    'wəː     P           L                      0  ...          NaN
#                                                                                                                                                           2      fore     fɔː      U           L                      0  ...          NaN
#                                                                                                                      3      do        1          'duː     1      do       'duː     P           L                      1  ...          NaN
#                                                                                                                                       2          duː      1      do       duː      U           L                      1  ...          NaN
# ...                                                                                                                                                                                                                 ...  ...          ...
#          14     And you must live, drawn by your own sweet skill. 2           drawn by your own sweet skill.         3      your      1          jɔːr     1      your     jɔːr     U           L                      1  ...          NaN
#                                                                                                                      4      own       1          'oʊn     1      own      'oʊn     P           L                      1  ...          NaN
#                                                                                                                                       2          oʊn      1      own      oʊn      U           L                      1  ...          NaN
#                                                                                                                      5      sweet     1          'swiːt   1      sweet    'swiːt   P           L                      0  ...          NaN
#                                                                                                                      6      skill.    1          'skɪl    1      skill.   'skɪl    P           L                      0  ...          NaN
#
# [164 rows x 10 columns]
