# %%
import sys; sys.path.insert(0,'/Users/ryan/github/prosodic/')
import sys; sys.path.insert(0,'/Users/ryan/github/cadence/')
from cadence.imports import *
# !rm -rf {PATH_DB}

# %%
text = Verse(sonnet+'\n\n'+sonnet)

# %%
text.words()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00,  9.52it/s]
# Empty DataFrame
# Columns: []
# Index: [(1, 1, 1, 1, 1, , How, how), (1, 1, 1, 1, 2,  , heavy, heavy), (1, 1, 1, 1, 3,  , do, do), (1, 1, 1, 1, 4,  , I, i), (1, 1, 1, 1, 5,  , journey, journey), (1, 1, 1, 1, 6,  , on, on), (1, 1, 1, 1, 7,  , the, the), (1, 1, 1, 1, 8,  , way,, way), (1, 1, 2, 2, 9,
#  , When, when), (1, 1, 2, 2, 10,  , what, what), (1, 1, 2, 2, 11,  , I, i), (1, 1, 2, 2, 12,  , seek,, seek), (1, 1, 3, 2, 13,  , my, my), (1, 1, 3, 2, 14,  , weary, weary), (1, 1, 3, 2, 15,  , travel's, travels), (1, 1, 3, 2, 16,  , end,, end), (1, 1, 4, 3, 17,
#  , Doth, doth), (1, 1, 4, 3, 18,  , teach, teach), (1, 1, 4, 3, 19,  , that, that), (1, 1, 4, 3, 20,  , ease, ease), (1, 1, 4, 3, 21,  , and, and), (1, 1, 4, 3, 22,  , that, that), (1, 1, 4, 3, 23,  , repose, repose), (1, 1, 4, 3, 24,  , to, to), (1, 1, 4, 3, 25,  , say, say), (1, 1, 4, 4, 26,
#  , 'Thus, thus), (1, 1, 4, 4, 27,  , far, far), (1, 1, 4, 4, 28,  , the, the), (1, 1, 4, 4, 29,  , miles, miles), (1, 1, 4, 4, 30,  , are, are), (1, 1, 4, 4, 31,  , measured, measured), (1, 1, 4, 4, 32,  , from, from), (1, 1, 4, 4, 33,  , thy, thy), (1, 1, 4, 4, 34,  , friend!', friend), (1, 2, 5, 5, 1,
#  , The, the), (1, 2, 5, 5, 2,  , beast, beast), (1, 2, 5, 5, 3,  , that, that), (1, 2, 5, 5, 4,  , bears, bears), (1, 2, 5, 5, 5,  , me,, me), (1, 2, 6, 5, 6,  , tired, tired), (1, 2, 6, 5, 7,  , with, with), (1, 2, 6, 5, 8,  , my, my), (1, 2, 6, 5, 9,  , woe,, woe), (1, 2, 7, 6, 10,
#  , Plods, plods), (1, 2, 7, 6, 11,  , dully, dully), (1, 2, 7, 6, 12,  , on,, on), (1, 2, 8, 6, 13,  , to, to), (1, 2, 8, 6, 14,  , bear, bear), (1, 2, 8, 6, 15,  , that, that), (1, 2, 8, 6, 16,  , weight, weight), (1, 2, 8, 6, 17,  , in, in), (1, 2, 8, 6, 18,  , me,, me), (1, 2, 9, 7, 19,
#  , As, as), (1, 2, 9, 7, 20,  , if, if), (1, 2, 9, 7, 21,  , by, by), (1, 2, 9, 7, 22,  , some, some), (1, 2, 9, 7, 23,  , instinct, instinct), (1, 2, 9, 7, 24,  , the, the), (1, 2, 9, 7, 25,  , wretch, wretch), (1, 2, 9, 7, 26,  , did, did), (1, 2, 9, 7, 27,  , know, know), (1, 2, 9, 8, 28,
#  , His, his), (1, 2, 9, 8, 29,  , rider, rider), (1, 2, 9, 8, 30,  , loved, loved), (1, 2, 9, 8, 31,  , not, not), (1, 2, 9, 8, 32,  , speed,, speed), (1, 2, 10, 8, 33,  , being, being), (1, 2, 10, 8, 34,  , made, made), (1, 2, 10, 8, 35,  , from, from), (1, 2, 10, 8, 36,  , thee:, thee), (1, 2, 11, 9, 37,
#  , The, the), (1, 2, 11, 9, 38,  , bloody, bloody), (1, 2, 11, 9, 39,  , spur, spur), (1, 2, 11, 9, 40,  , cannot, cannot), (1, 2, 11, 9, 41,  , provoke, provoke), (1, 2, 11, 9, 42,  , him, him), (1, 2, 11, 9, 43,  , on, on), (1, 2, 11, 10, 44,
#  , That, that), (1, 2, 11, 10, 45,  , sometimes, sometimes), (1, 2, 11, 10, 46,  , anger, anger), (1, 2, 11, 10, 47,  , thrusts, thrusts), (1, 2, 11, 10, 48,  , into, into), (1, 2, 11, 10, 49,  , his, his), (1, 2, 11, 10, 50,  , hide;, hide), (1, 2, 12, 11, 51,
#  , Which, which), (1, 2, 12, 11, 52,  , heavily, heavily), (1, 2, 12, 11, 53,  , he, he), (1, 2, 12, 11, 54,  , answers, answers), (1, 2, 12, 11, 55,  , with, with), (1, 2, 12, 11, 56,  , a, a), (1, 2, 12, 11, 57,  , groan,, groan), (1, 2, 13, 12, 58,
#  , More, more), (1, 2, 13, 12, 59,  , sharp, sharp), (1, 2, 13, 12, 60,  , to, to), (1, 2, 13, 12, 61,  , me, me), (1, 2, 13, 12, 62,  , than, than), (1, 2, 13, 12, 63,  , spurring, spurring), (1, 2, 13, 12, 64,  , to, to), (1, 2, 13, 12, 65,  , his, his), (1, 2, 13, 12, 66,  , side;, side), ...]
#
# [236 rows x 0 columns]

# %%
text.num_words
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 39945.75it/s]
# 236

# %%
text.sents()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 40920.04it/s]
# [<Sentence #1: How heavy do I journey on the way, When what I seek, my weary travel's end, Doth teach that ease and that repose to say 'Thus far the miles are measured from thy friend!'>,
#  <Sentence #2:  The beast that bears me, tired with my woe, Plods dully on, to bear that weight in me, As if by some instinct the wretch did know His rider loved not speed, being made from thee: The bloody spur cannot provoke him on That sometimes anger thrusts into his hide; Which heavily he answers with a groan, More sharp to me than spurring to his side; For that same groan doth put this in my mind; My grief lies onward and my joy behind.>,
#  <Sentence #1: How heavy do I journey on the way, When what I seek, my weary travel's end, Doth teach that ease and that repose to say 'Thus far the miles are measured from thy friend!'>,
#  <Sentence #2:  The beast that bears me, tired with my woe, Plods dully on, to bear that weight in me, As if by some instinct the wretch did know His rider loved not speed, being made from thee: The bloody spur cannot provoke him on That sometimes anger thrusts into his hide; Which heavily he answers with a groan, More sharp to me than spurring to his side; For that same groan doth put this in my mind; My grief lies onward and my joy behind.>]

# %%
text.sent(3)
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 46603.38it/s]
# <Sentence #1: How heavy do I journey on the way, When what I seek, my weary travel's end, Doth teach that ease and that repose to say 'Thus far the miles are measured from thy friend!'>

# %%
text.sent((2,1))
# Out:
# <Sentence #1: How heavy do I journey on the way, When what I seek, my weary travel's end, Doth teach that ease and that repose to say 'Thus far the miles are measured from thy friend!'>

# %%
text.num_sents
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 8160.12it/s]
# 4

# %%
text.fsent_str
# Out:
# "How heavy do I journey on the way,\nWhen what I seek, my weary travel's end,\nDoth teach that ease and that repose to say\n'Thus far the miles are measured from thy friend!'"

# %%
text.lsent_str
# Out:
# '\nThe beast that bears me, tired with my woe,\nPlods dully on, to bear that weight in me,\nAs if by some instinct the wretch did know\nHis rider loved not speed, being made from thee:\nThe bloody spur cannot provoke him on\nThat sometimes anger thrusts into his hide;\nWhich heavily he answers with a groan,\nMore sharp to me than spurring to his side;\nFor that same groan doth put this in my mind;\nMy grief lies onward and my joy behind.'

# %%
text.sylls()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 24456.58it/s]
#                                                                                                                                           prom_strength  ...  word_nsyll
# para_i sent_i sentpart_i line_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress syll_weight                 ...
# 1      1      1          1      1                How      how      1          haʊ       1      how      haʊ      U           H                      NaN  ...           1
#                                 2                heavy    heavy    1          'hɛ.viː   1      hea      'hɛ      P           L                      1.0  ...           2
#                                                                                         2      vy       viː      U           L                      0.0  ...           2
#                                 3                do       do       1          'duː      1      do       'duː     P           L                      1.0  ...           1
#                                                                    2          duː       1      do       duː      U           L                      0.0  ...           1
# ...                                                                                                                                                 ...  ...         ...
# 2      2      15         14     81               and      and      1          ænd       1      and      ænd      U           H                      NaN  ...           1
#                                 82               my       my       1          maɪ       1      my       maɪ      U           H                      NaN  ...           1
#                                 83               joy      joy      1          'ʤɔɪ      1      joy      'ʤɔɪ     P           H                      NaN  ...           1
#                                 84               behind.  behind   1          bɪ.'haɪnd 1      be       bɪ       U           L                      0.0  ...           2
#                                                                                         2      hind     'haɪnd   P           H                      1.0  ...           2
#
# [340 rows x 5 columns]

# %%
text.syntax()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 66576.25it/s]
#                                dep_head   dep_type  ... pos_xpos word_depth
# para_i sent_i word_i word_str                       ...
# 1      1      1      How              2     advmod  ...      WRB          5
#               2      heavy            5     advmod  ...       JJ          6
#               3      do               5        aux  ...      VBP          4
#               4      I                5      nsubj  ...      PRP          5
#               5      journey          0       root  ...       VB          5
# ...                                 ...        ...  ...      ...        ...
# 2      2      80     onward          79     advmod  ...       RB          8
#               81     and             84         cc  ...       CC          3
#               82     my              84  nmod:poss  ...     PRP$          5
#               83     joy             84   compound  ...       NN          5
#               84     behind.         79       conj  ...       NN          5
#
# [236 rows x 17 columns]

# %%
text.mtrees()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 41734.37it/s]
#                                mtree_ishead  ...  prom_tstress
# para_i sent_i word_i word_str                ...
# 1      1      1      How                NaN  ...      0.000000
#               2      heavy              NaN  ...      0.750000
#               3      do                 NaN  ...      0.250000
#               4      I                  NaN  ...      0.250000
#               5      journey            NaN  ...      0.750000
# ...                                     ...  ...           ...
# 2      2      80     onward             NaN  ...      0.857143
#               81     and                NaN  ...      0.714286
#               82     my                 0.0  ...      0.714286
#               83     joy                0.0  ...      1.000000
#               84     behind.            1.0  ...      0.857143
#
# [236 rows x 5 columns]

# %%
text.data()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 52758.54it/s]
#                                                                                                                                           dep_head  ... word_nsyll
# para_i sent_i sentpart_i line_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress syll_weight            ...
# 1      1      1          1      1                How      how      1          haʊ       1      how      haʊ      U           H                   2  ...          1
#                                 2                heavy    heavy    1          'hɛ.viː   1      hea      'hɛ      P           L                   5  ...          2
#                                                                                         2      vy       viː      U           L                   5  ...          2
#                                 3                do       do       1          'duː      1      do       'duː     P           L                   5  ...          1
#                                                                    2          duː       1      do       duː      U           L                   5  ...          1
# ...                                                                                                                                            ...  ...        ...
# 2      2      15         14     81               and      and      1          ænd       1      and      ænd      U           H                  84  ...          1
#                                 82               my       my       1          maɪ       1      my       maɪ      U           H                  84  ...          1
#                                 83               joy      joy      1          'ʤɔɪ      1      joy      'ʤɔɪ     P           H                  84  ...          1
#                                 84               behind.  behind   1          bɪ.'haɪnd 1      be       bɪ       U           L                  79  ...          2
#                                                                                         2      hind     'haɪnd   P           H                  79  ...          2
#
# [340 rows x 27 columns]

# %%
text.parses()
# Out:
# Iterating over paragraphs: 100%|██████████| 2/2 [00:00<00:00, 62601.55it/s]
#                                                                                                                                                                                                        *total  ...  word_nsyll
# para_i sent_i sentpart_i unit_i line_i parse_rank is_troch parse_i parse      combo_i slot_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress syll_weight          ...
# 1      1      1          1      1      1          0        1       wSwSwSwSwS 2       1      1                How      how      1          haʊ       1      how      haʊ      U           H               0.0  ...           1
#                                                                                       2      2                heavy    heavy    1          'hɛ.viː   1      hea      'hɛ      P           L               0.0  ...           2
#                                                                                       3      2                heavy    heavy    1          'hɛ.viː   2      vy       viː      U           L               0.0  ...           2
#                                                                                       4      3                do       do       1          'duː      1      do       'duː     P           L               0.0  ...           1
#                                                                                       5      4                I        i        2          aɪ        1      i        aɪ       U           H               0.0  ...           1
# ...                                                                                                                                                                                                       ...  ...         ...
# 2      2      15         14     14     1          0        1       wSwSwSwSwS 1       6      81               and      and      1          ænd       1      and      ænd      U           H               1.0  ...           1
#                                                                                       7      82               my       my       1          maɪ       1      my       maɪ      U           H               0.0  ...           1
#                                                                                       8      83               joy      joy      1          'ʤɔɪ      1      joy      'ʤɔɪ     P           H               0.0  ...           1
#                                                                                       9      84               behind.  behind   1          bɪ.'haɪnd 1      be       bɪ       U           L               0.0  ...           2
#                                                                                       10     84               behind.  behind   1          bɪ.'haɪnd 2      hind     'haɪnd   P           H               0.0  ...           2
#
# [584 rows x 35 columns]
