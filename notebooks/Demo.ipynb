# %% [markdown]
# # Cadence

# %%
import sys; sys.path.append('..')
import cadence as cd

# %%
# grab a string of a poem or text
milton="""
OF Mans First Disobedience, and the Fruit
Of that Forbidden Tree, whose mortal tast
Brought Death into the World, and all our woe
"""

# %%
# load as a dataframe
txtdf = cd.load('into the woods')
txtdf
# Out:
#                                                                                                          is_peak  is_stressed  ...  prom_strength  prom_stress
# stanza_i line_i line_str       word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_stress                        ...
# 0        0      into the woods 0      into     0          ɪn.'tuː  0      in       ɪn       U                  0            0  ...            0.0          0.0
#                                                                    1      to       'tuː     P                  1            1  ...            1.0          1.0
#                                                1          'ɪn.tuː  0      in       'ɪn      P                  1            1  ...            1.0          1.0
#                                                                    1      to       tuː      U                  0            0  ...            0.0          0.0
# ...

# %%
for linedf in cd.iter_combos(txtdf):
    display(linedf)
# Out:
# Index(['stanza_i', 'line_i', 'line_str', 'word_i', 'word_str', 'word_ipa_i',
#        'word_ipa', 'syll_i', 'syll_str', 'syll_ipa', 'syll_stress', 'is_peak',
#        'is_stressed', 'is_syll', 'is_trough', 'is_unstressed', 'prom_strength',
#        'prom_stress'],
#       dtype='object') True
#                                                                                                                                                             combo_num_syll  ...  prom_stress
# stanza_i line_i line_str       combo_i combo_stress combo_ipa        word_i word_str word_ipa_i word_ipa syll_i combo_syll_i syll_str syll_ipa syll_stress                  ...
# 0        0      into the woods 0       UPUP         ɪn.'tuː ðə 'wʊdz 0      into     0          ɪn.'tuː  0      0            in       ɪn       U                         4  ...          0.0
# ...

# %%
# Data by line
parses = cd.parse(txtdf,num_proc=1)
parses
# Out:
# Metrically parsing lines (+word IPA combinations) [x1]:   0%|          | 0/3 [00:00<?, ?it/s]
# True
# True !?!?!
# Index(['stanza_i', 'line_i', 'line_str', 'word_i', 'word_str', 'word_ipa_i',
#        'word_ipa', 'syll_i', 'syll_str', 'syll_ipa', 'syll_stress', 'is_peak',
#        'is_stressed', 'is_syll', 'is_trough', 'is_unstressed', 'prom_strength',
#        'prom_stress'],
#       dtype='object') True
# Metrically parsing lines (+word IPA combinations) [x1]: 100%|██████████| 3/3 [00:00<00:00,  3.11it/s]
#                                                                                                     parse_rank  *total  ...  prom_strength  prom_stress
# stanza_i line_i line_str       combo_i combo_stress combo_ipa        parse_i parse parse_str                            ...
# 0        0      into the woods 0       UPUP         ɪn.'tuː ðə 'wʊdz 0       wsws  in.TO|the|WOODS           1       0  ...            1.0          2.0
# ...

# %%
# Even more detail
parses_bysyll = cd.parse(parses,data_by_syll=True)
parses_bysyll
# Out:
# False
# False !?!?!
# Index(['stanza_i', 'line_i', 'line_str', 'combo_i', 'combo_stress',
#        'combo_ipa', 'parse_i', 'parse', 'parse_str', 'parse_rank', '*total',
#        '*clash', '*lapse', '*s/unstressed', '*w/peak', '*w/stressed',
#        'combo_num_syll', 'is_peak', 'is_s', 'is_stressed', 'is_syll',
#        'is_trough', 'is_unstressed', 'is_w', 'parse_num_pos', 'parse_num_syll',
#        'prom_strength', 'prom_stress'],
#       dtype='object') False
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2dba01657f1c> in <module>
#       1 # Even more detail
# ----> 2 parses_bysyll = cd.parse(parses,data_by_syll=True)
#       3 parses_bysyll
#
# ~/github/cadence/cadence/parsers/metrics.py in parse(txtdf, *x, **y)
#     334     Return parses
#     335     """
# --> 336     return pd.concat(parse_iter(txtdf,*x, **y))
#     337
#     338
#
# ...

# %%
for combo in cd.iter_combos(txtdf):
    display(combo)
