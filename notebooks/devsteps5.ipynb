# %%
import sys; sys.path.append('..')
import prosodic2 as p
from prosodic2 import *
from tqdm import tqdm
import pandas as pd

# %%
pd.options.display.max_columns=None
pd.options.display.max_rows=25

# %%
txt="""
Shall I compare thee to a summer's day?
Thou art more lovely and more temperate:
Rough winds do shake the darling buds of May,
And summer's lease hath all too short a date;
Sometime too hot the eye of heaven shines,
And often is his gold complexion dimm'd;
And every fair from fair sometime declines,
By chance or nature's changing course untrimm'd;
But thy eternal summer shall not fade,
Nor lose possession of that fair thou ow'st;
Nor shall death brag thou wander'st in his shade,
When in eternal lines to time thou grow'st:
   So long as men can breathe or eyes can see,
   So long lives this, and this gives life to thee.

"""

# %%
# txt="Into the woods we go"

# %% [markdown]
# ## Loading text

# %%
txtdf = parse_phon(txt)
txtdf
# Out:
# Tokenizing and syllabifying [x1]: 100%|██████████| 14/14 [00:00<00:00, 17.63it/s]
#                                                                                       prom_strength  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl                1.0
#                 1       1      I        0          'aɪ      0      I        'aɪ                 1.0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm                 1.0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr                1.0
#                 4       3      thee     0          ðiː      0      thee     ðiː                 1.0
# ...                                                                                             ...
#          13     7       7      gives    0          'gɪvz    0      gives    'gɪvz               NaN
#                 8       8      life     0          'laɪf    0      life     'laɪf               NaN
#                 9       9      to       0          tuː      0      to       tuː                 NaN
#                 10      10     thee     0          ðiː      0      thee     ðiː                 NaN
#                 11      11     .        0                   0      .                            NaN
#
#                                                                                       is_peak  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl            1
#                 1       1      I        0          'aɪ      0      I        'aɪ             1
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm             1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr            1
#                 4       3      thee     0          ðiː      0      thee     ðiː             1
# ...                                                                                       ...
#          13     7       7      gives    0          'gɪvz    0      gives    'gɪvz           0
#                 8       8      life     0          'laɪf    0      life     'laɪf           0
#                 9       9      to       0          tuː      0      to       tuː             0
#                 10      10     thee     0          ðiː      0      thee     ðiː             0
#                 11      11     .        0                   0      .                        0
#
#                                                                                       is_stressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl                1
#                 1       1      I        0          'aɪ      0      I        'aɪ                 1
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm                 0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr                1
#                 4       3      thee     0          ðiː      0      thee     ðiː                 0
# ...                                                                                           ...
#          13     7       7      gives    0          'gɪvz    0      gives    'gɪvz               1
#                 8       8      life     0          'laɪf    0      life     'laɪf               1
#                 9       9      to       0          tuː      0      to       tuː                 0
#                 10      10     thee     0          ðiː      0      thee     ðiː                 0
#                 11      11     .        0                   0      .                            0
#
#                                                                                       is_unstressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl                  0
#                 1       1      I        0          'aɪ      0      I        'aɪ                   0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm                   1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr                  0
#                 4       3      thee     0          ðiː      0      thee     ðiː                   1
# ...                                                                                             ...
#          13     7       7      gives    0          'gɪvz    0      gives    'gɪvz                 0
#                 8       8      life     0          'laɪf    0      life     'laɪf                 0
#                 9       9      to       0          tuː      0      to       tuː                   1
#                 10      10     thee     0          ðiː      0      thee     ðiː                   1
#                 11      11     .        0                   0      .                              1
#
#                                                                                       prom_stress  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl              1.0
#                 1       1      I        0          'aɪ      0      I        'aɪ               1.0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm               0.0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr              1.0
#                 4       3      thee     0          ðiː      0      thee     ðiː               0.0
# ...                                                                                           ...
#          13     7       7      gives    0          'gɪvz    0      gives    'gɪvz             1.0
#                 8       8      life     0          'laɪf    0      life     'laɪf             1.0
#                 9       9      to       0          tuː      0      to       tuː               0.0
#                 10      10     thee     0          ðiː      0      thee     ðiː               0.0
#                 11      11     .        0                   0      .                          NaN
#
#                                                                                       is_trough
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl              0
#                 1       1      I        0          'aɪ      0      I        'aɪ               0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm               0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr              0
#                 4       3      thee     0          ðiː      0      thee     ðiː               0
# ...                                                                                         ...
#          13     7       7      gives    0          'gɪvz    0      gives    'gɪvz             0
#                 8       8      life     0          'laɪf    0      life     'laɪf             0
#                 9       9      to       0          tuː      0      to       tuː               0
#                 10      10     thee     0          ðiː      0      thee     ðiː               0
#                 11      11     .        0                   0      .                          0
#
# [191 rows x 6 columns]

# %%
def iter_lines(txtdf):
    for stanza_i,stanzadf in txtdf.groupby('stanza_i'):
        lines=tqdm(list(stanzadf.groupby('line_i')),desc='Scanning through lines')
        for line_,linedf in lines:
            yield linedf

# %%
for line_df in iter_lines(txtdf): pass
line_df
# Out:
# Scanning through lines: 100%|██████████| 14/14 [00:00<00:00, 90338.86it/s]
#                                                                                       prom_strength  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ                NaN
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ               NaN
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz               NaN
#                 3       3      this     0          ðɪs      0      this     ðɪs                 NaN
#                 4       4      ,        0                   0      ,                            NaN
#                 5       5      and      0          ænd      0      and      ænd                 NaN
#                 6       6      this     0          ðɪs      0      this     ðɪs                 NaN
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz               NaN
#                 8       8      life     0          'laɪf    0      life     'laɪf               NaN
#                 9       9      to       0          tuː      0      to       tuː                 NaN
#                 10      10     thee     0          ðiː      0      thee     ðiː                 NaN
#                 11      11     .        0                   0      .                            NaN
#
#                                                                                       is_peak  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ            0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ           0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz           0
#                 3       3      this     0          ðɪs      0      this     ðɪs             0
#                 4       4      ,        0                   0      ,                        0
#                 5       5      and      0          ænd      0      and      ænd             0
#                 6       6      this     0          ðɪs      0      this     ðɪs             0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz           0
#                 8       8      life     0          'laɪf    0      life     'laɪf           0
#                 9       9      to       0          tuː      0      to       tuː             0
#                 10      10     thee     0          ðiː      0      thee     ðiː             0
#                 11      11     .        0                   0      .                        0
#
#                                                                                       is_stressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ                1
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ               1
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz               1
#                 3       3      this     0          ðɪs      0      this     ðɪs                 0
#                 4       4      ,        0                   0      ,                            0
#                 5       5      and      0          ænd      0      and      ænd                 0
#                 6       6      this     0          ðɪs      0      this     ðɪs                 0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz               1
#                 8       8      life     0          'laɪf    0      life     'laɪf               1
#                 9       9      to       0          tuː      0      to       tuː                 0
#                 10      10     thee     0          ðiː      0      thee     ðiː                 0
#                 11      11     .        0                   0      .                            0
#
#                                                                                       is_unstressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ                  0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ                 0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz                 0
#                 3       3      this     0          ðɪs      0      this     ðɪs                   1
#                 4       4      ,        0                   0      ,                              1
#                 5       5      and      0          ænd      0      and      ænd                   1
#                 6       6      this     0          ðɪs      0      this     ðɪs                   1
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz                 0
#                 8       8      life     0          'laɪf    0      life     'laɪf                 0
#                 9       9      to       0          tuː      0      to       tuː                   1
#                 10      10     thee     0          ðiː      0      thee     ðiː                   1
#                 11      11     .        0                   0      .                              1
#
#                                                                                       prom_stress  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ              1.0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ             1.0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz             1.0
#                 3       3      this     0          ðɪs      0      this     ðɪs               0.0
#                 4       4      ,        0                   0      ,                          NaN
#                 5       5      and      0          ænd      0      and      ænd               0.0
#                 6       6      this     0          ðɪs      0      this     ðɪs               0.0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz             1.0
#                 8       8      life     0          'laɪf    0      life     'laɪf             1.0
#                 9       9      to       0          tuː      0      to       tuː               0.0
#                 10      10     thee     0          ðiː      0      thee     ðiː               0.0
#                 11      11     .        0                   0      .                          NaN
#
#                                                                                       is_trough
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ              0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ             0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz             0
#                 3       3      this     0          ðɪs      0      this     ðɪs               0
#                 4       4      ,        0                   0      ,                          0
#                 5       5      and      0          ænd      0      and      ænd               0
#                 6       6      this     0          ðɪs      0      this     ðɪs               0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz             0
#                 8       8      life     0          'laɪf    0      life     'laɪf             0
#                 9       9      to       0          tuː      0      to       tuː               0
#                 10      10     thee     0          ðiː      0      thee     ðiː               0
#                 11      11     .        0                   0      .                          0

# %% [markdown]
# ## Looping windows

# %%
def iter_windows(df,window_len=3):
    for linedf in iter_lines(df):
        ldf=linedf.reset_index()
        linedf_nopunc = ldf[ldf.word_ipa!=""]
        linewords=[g for n,g in linedf_nopunc.groupby('word_i')]
        for wordslice in slices(linewords,window_len,strict=True):
            dfslice=pd.concat(wordslice)
            yield setindex(dfslice)

# %%
for dfw in iter_windows(line_df): break #display(dfw)
dfw
# Out:
# Scanning through lines:   0%|          | 0/1 [00:00<?, ?it/s]
#                                                                                       prom_strength  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ                NaN
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ               NaN
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz               NaN
#
#                                                                                       is_peak  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ            0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ           0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz           0
#
#                                                                                       is_stressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ                1
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ               1
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz               1
#
#                                                                                       is_unstressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ                  0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ                 0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz                 0
#
#                                                                                       prom_stress  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ              1.0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ             1.0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz             1.0
#
#                                                                                       is_trough
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0      So       0          'soʊ     0      So       'soʊ              0
#                 1       1      long     0          'lɔːŋ    0      long     'lɔːŋ             0
#                 2       2      lives    0          'lɪvz    0      lives    'lɪvz             0

# %% [markdown]
# ## Combos

# %%
def iter_combos(df):
    # get all combos in window/line
    for lci,dfcombo in enumerate(apply_combos(df,'word_i','word_ipa_i')):
        dfcombo['combo_i']=lci
        dfcombo['combo_ii']=list(range(len(dfcombo)))
        yield setindex(dfcombo)

# %%
for dfc in iter_combos(dfw): pass
dfc
# Out:
#                                                                                                        prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0       0        0      So       0          'soʊ     0      So       'soʊ                NaN
#                 1       0       1        1      long     0          'lɔːŋ    0      long     'lɔːŋ               NaN
#                 2       0       2        2      lives    0          'lɪvz    0      lives    'lɪvz               NaN
#
#                                                                                                        is_peak  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0       0        0      So       0          'soʊ     0      So       'soʊ            0
#                 1       0       1        1      long     0          'lɔːŋ    0      long     'lɔːŋ           0
#                 2       0       2        2      lives    0          'lɪvz    0      lives    'lɪvz           0
#
#                                                                                                        is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0       0        0      So       0          'soʊ     0      So       'soʊ                1
#                 1       0       1        1      long     0          'lɔːŋ    0      long     'lɔːŋ               1
#                 2       0       2        2      lives    0          'lɪvz    0      lives    'lɪvz               1
#
#                                                                                                        prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0       0        0      So       0          'soʊ     0      So       'soʊ              1.0
#                 1       0       1        1      long     0          'lɔːŋ    0      long     'lɔːŋ             1.0
#                 2       0       2        2      lives    0          'lɪvz    0      lives    'lɪvz             1.0
#
#                                                                                                        is_trough  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0       0        0      So       0          'soʊ     0      So       'soʊ              0
#                 1       0       1        1      long     0          'lɔːŋ    0      long     'lɔːŋ             0
#                 2       0       2        2      lives    0          'lɪvz    0      lives    'lɪvz             0
#
#                                                                                                        is_unstressed
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     0       0       0        0      So       0          'soʊ     0      So       'soʊ                  0
#                 1       0       1        1      long     0          'lɔːŋ    0      long     'lɔːŋ                 0
#                 2       0       2        2      lives    0          'lɪvz    0      lives    'lɪvz                 0

# %%
def iter_all_combos(df):
    for dfw in iter_windows(df):
        for dfc in iter_combos(dfw):
            yield dfc

# %%
for dfc in iter_all_combos(txtdf): pass
dfc
# Out:
# Scanning through lines: 100%|██████████| 14/14 [00:03<00:00,  4.49it/s]
#                                                                                                        prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     8       0       0        8      life     0          'laɪf    0      life     'laɪf               NaN
#                 9       0       1        9      to       0          tuː      0      to       tuː                 NaN
#                 10      0       2        10     thee     0          ðiː      0      thee     ðiː                 NaN
#
#                                                                                                        is_peak  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     8       0       0        8      life     0          'laɪf    0      life     'laɪf           0
#                 9       0       1        9      to       0          tuː      0      to       tuː             0
#                 10      0       2        10     thee     0          ðiː      0      thee     ðiː             0
#
#                                                                                                        is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     8       0       0        8      life     0          'laɪf    0      life     'laɪf               1
#                 9       0       1        9      to       0          tuː      0      to       tuː                 0
#                 10      0       2        10     thee     0          ðiː      0      thee     ðiː                 0
#
#                                                                                                        prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     8       0       0        8      life     0          'laɪf    0      life     'laɪf             1.0
#                 9       0       1        9      to       0          tuː      0      to       tuː               0.0
#                 10      0       2        10     thee     0          ðiː      0      thee     ðiː               0.0
#
#                                                                                                        is_trough  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     8       0       0        8      life     0          'laɪf    0      life     'laɪf             0
#                 9       0       1        9      to       0          tuː      0      to       tuː               0
#                 10      0       2        10     thee     0          ðiː      0      thee     ðiː               0
#
#                                                                                                        is_unstressed
# stanza_i line_i line_ii combo_i combo_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa
# 0        13     8       0       0        8      life     0          'laɪf    0      life     'laɪf                 0
#                 9       0       1        9      to       0          tuː      0      to       tuː                   1
#                 10      0       2        10     thee     0          ðiː      0      thee     ðiː                   1

# %%
dfcall=pd.concat(iter_all_combos(txtdf)).reset_index()
dfcall=dfcall[dfcall.line_i<2]
dfcall=setindex(dfcall)
dfcall
# Out:
# Scanning through lines: 100%|██████████| 14/14 [00:03<00:00,  4.55it/s]
#                                                                                                            prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str  word_ipa_i word_ipa    syll_i syll_str syll_ipa
# 0        0      0       0       0        0      Shall     0          'ʃæl        0      Shall    'ʃæl                1.0
#                 1       0       0        1      I         0          'aɪ         0      I        'aɪ                 1.0
#                                 1        1      I         0          'aɪ         0      I        'aɪ                 1.0
#                 2       0       0        2      compare   0          kəm.'pɛr    0      com      kəm                 1.0
#                                 1        2      compare   0          kəm.'pɛr    0      com      kəm                 1.0
# ...                                                                                                                  ...
#          1      12      3       2        6      temperate 1          'tɛm.pɛː.ət 0      tem      'tɛm                1.0
#                 13      1       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː                 1.0
#                         3       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː                 1.0
#                 14      1       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                  0.0
#                         3       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                  0.0
#
#                                                                                                            is_peak  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str  word_ipa_i word_ipa    syll_i syll_str syll_ipa
# 0        0      0       0       0        0      Shall     0          'ʃæl        0      Shall    'ʃæl            1
#                 1       0       0        1      I         0          'aɪ         0      I        'aɪ             1
#                                 1        1      I         0          'aɪ         0      I        'aɪ             1
#                 2       0       0        2      compare   0          kəm.'pɛr    0      com      kəm             1
#                                 1        2      compare   0          kəm.'pɛr    0      com      kəm             1
# ...                                                                                                            ...
#          1      12      3       2        6      temperate 1          'tɛm.pɛː.ət 0      tem      'tɛm            1
#                 13      1       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː             1
#                         3       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː             1
#                 14      1       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət              0
#                         3       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət              0
#
#                                                                                                            is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str  word_ipa_i word_ipa    syll_i syll_str syll_ipa
# 0        0      0       0       0        0      Shall     0          'ʃæl        0      Shall    'ʃæl                1
#                 1       0       0        1      I         0          'aɪ         0      I        'aɪ                 1
#                                 1        1      I         0          'aɪ         0      I        'aɪ                 1
#                 2       0       0        2      compare   0          kəm.'pɛr    0      com      kəm                 0
#                                 1        2      compare   0          kəm.'pɛr    0      com      kəm                 0
# ...                                                                                                                ...
#          1      12      3       2        6      temperate 1          'tɛm.pɛː.ət 0      tem      'tɛm                1
#                 13      1       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː                 0
#                         3       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː                 0
#                 14      1       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                  0
#                         3       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                  0
#
#                                                                                                            is_unstressed  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str  word_ipa_i word_ipa    syll_i syll_str syll_ipa
# 0        0      0       0       0        0      Shall     0          'ʃæl        0      Shall    'ʃæl                  0
#                 1       0       0        1      I         0          'aɪ         0      I        'aɪ                   0
#                                 1        1      I         0          'aɪ         0      I        'aɪ                   0
#                 2       0       0        2      compare   0          kəm.'pɛr    0      com      kəm                   1
#                                 1        2      compare   0          kəm.'pɛr    0      com      kəm                   1
# ...                                                                                                                  ...
#          1      12      3       2        6      temperate 1          'tɛm.pɛː.ət 0      tem      'tɛm                  0
#                 13      1       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː                   1
#                         3       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː                   1
#                 14      1       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                    1
#                         3       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                    1
#
#                                                                                                            prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii word_i word_str  word_ipa_i word_ipa    syll_i syll_str syll_ipa
# 0        0      0       0       0        0      Shall     0          'ʃæl        0      Shall    'ʃæl              1.0
#                 1       0       0        1      I         0          'aɪ         0      I        'aɪ               1.0
#                                 1        1      I         0          'aɪ         0      I        'aɪ               1.0
#                 2       0       0        2      compare   0          kəm.'pɛr    0      com      kəm               0.0
#                                 1        2      compare   0          kəm.'pɛr    0      com      kəm               0.0
# ...                                                                                                                ...
#          1      12      3       2        6      temperate 1          'tɛm.pɛː.ət 0      tem      'tɛm              1.0
#                 13      1       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː               0.0
#                         3       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː               0.0
#                 14      1       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                0.0
#                         3       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                0.0
#
#                                                                                                            is_trough
# stanza_i line_i line_ii combo_i combo_ii word_i word_str  word_ipa_i word_ipa    syll_i syll_str syll_ipa
# 0        0      0       0       0        0      Shall     0          'ʃæl        0      Shall    'ʃæl              0
#                 1       0       0        1      I         0          'aɪ         0      I        'aɪ               0
#                                 1        1      I         0          'aɪ         0      I        'aɪ               0
#                 2       0       0        2      compare   0          kəm.'pɛr    0      com      kəm               0
#                                 1        2      compare   0          kəm.'pɛr    0      com      kəm               0
# ...                                                                                                              ...
#          1      12      3       2        6      temperate 1          'tɛm.pɛː.ət 0      tem      'tɛm              0
#                 13      1       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː               0
#                         3       3        6      temperate 1          'tɛm.pɛː.ət 1      per      pɛː               0
#                 14      1       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                1
#                         3       4        6      temperate 1          'tɛm.pɛː.ət 2      ate      ət                1
#
# [85 rows x 6 columns]

# %% [markdown]
# ## Parses

# %%
def iter_poss_parses(df):
    for posi,posl in enumerate(possible_parses(len(df))):
        df['parse_i']=posi
        df['parse_ii']=list(range(len(posl)))
        df['parse']=''.join(posl)
        df['syll_parse']=list(posl)
        df['is_w']=[np.int(x=='w') for x in posl]
        df['is_s']=[np.int(x=='s') for x in posl]
        yield setindex(df)

# %%
for dfp in iter_poss_parses(dfc): pass
dfp
# Out:
#                                                                                                                                          prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     NaN
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     NaN
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     NaN
#
#                                                                                                                                          is_peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   1.0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0.0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0.0
#
#                                                                                                                                          is_s  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              0
#
#                                                                                                                                          is_w  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              1
#
#                                                                                                                                          is_trough  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0
#
#                                                                                                                                          is_unstressed
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       1

# %%
def parse_group(df,constraints=DEFAULT_CONSTRAINTS):
    dfpc=apply_constraints(df)
    lkeys=[c for c in df.columns if c not in set(dfpc.columns)]
    return df[lkeys].join(dfpc)

# %%
parse_group(dfp)
# Out:
#                                                                                                                                          prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     NaN
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     NaN
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     NaN
#
#                                                                                                                                          is_peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   1.0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0.0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0.0
#
#                                                                                                                                          is_s  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              0
#
#                                                                                                                                          is_w  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              1
#
#                                                                                                                                          is_trough  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0
#
#                                                                                                                                          is_unstressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       1
#
#                                                                                                                                          *w/stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          *s/unstressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       0
#
#                                                                                                                                          *w/peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          *total
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                0

# %%
def iter_parsed(df):
    for pi,dfp in enumerate(iter_poss_parses(df)):
        dfpc=parse_group(dfp)
        yield dfpc

# %%
for dfpc in iter_parsed(dfp): pass
dfpc
# Out:
#                                                                                                                                          prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     NaN
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     NaN
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     NaN
#
#                                                                                                                                          is_peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   1.0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0.0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0.0
#
#                                                                                                                                          is_s  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              0
#
#                                                                                                                                          is_w  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              1
#
#                                                                                                                                          is_trough  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0
#
#                                                                                                                                          is_unstressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       1
#
#                                                                                                                                          *w/stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          *s/unstressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       0
#
#                                                                                                                                          *w/peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          *total
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        13     8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                0

# %%
def iter_all_parsed(df):
    for dfc in iter_all_combos(txtdf):
        yield from iter_parsed(dfc)

# %%
# for dfpc in iter_all_parsed(dfc): pass
# dfpc

# %% [markdown]
# ## Parallel?

# %%
def get_parsed(df):
#     print('--> get_parsed',df)
    gen=iter_parsed(df)
    return list(gen)

# %%
# get_parsed(dfc)

# %%
def get_all_parsed(txtdf):
    # get all combos
    objs=list(iter_all_combos(txtdf))
    # map
    res=pmap(
        get_parsed,
        objs,
        num_proc=7
    )
    # return df
    resdf=pd.concat([x for y in res for x in y])
    return resdf

# %%
df_all_parsed = get_all_parsed(txtdf)
df_all_parsed
# Out:
# Scanning through lines: 100%|██████████| 14/14 [00:03<00:00,  4.62it/s]
# Mapping get_parsed() [x7]: 100%|██████████| 133/133 [00:01<00:00, 70.03it/s]
#                                                                                                                                          prom_strength  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                     1.0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                     1.0
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                     1.0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                     1.0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                     1.0
# ...                                                                                                                                                ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                     NaN
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                     NaN
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     NaN
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     NaN
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     NaN
#
#                                                                                                                                          is_peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                 1
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                 1
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                 1
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                 1
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                 1
# ...                                                                                                                                          ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                 0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          is_stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                     1
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                     1
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                     0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                     1
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                     1
# ...                                                                                                                                              ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                     0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          prom_stress  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                   1.0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                   1.0
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                   0.0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                   1.0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                   1.0
# ...                                                                                                                                              ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                   0.0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                   0.0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   1.0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0.0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0.0
#
#                                                                                                                                          is_s  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s              1
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w              0
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w              0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s              1
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w              0
# ...                                                                                                                                       ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s              1
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s              1
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              1
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              0
#
#                                                                                                                                          is_w  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s              0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w              1
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w              1
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s              0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w              1
# ...                                                                                                                                       ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s              0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s              0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s              0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s              0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w              1
#
#                                                                                                                                          is_trough  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                   0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                   0
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                   0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                   0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                   0
# ...                                                                                                                                            ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                   0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                   0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                   0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                   0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                   0
#
#                                                                                                                                          is_unstressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                       0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                       0
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                       1
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                       0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                       0
# ...                                                                                                                                                ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                       1
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       1
#
#                                                                                                                                          *w/stressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                     0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                     1
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                     0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                     0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                     1
# ...                                                                                                                                              ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                     0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                     0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                     0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                                                          *s/unstressed  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                       0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                       0
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                       0
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                       0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                       0
# ...                                                                                                                                                ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                       1
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                       0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                       1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                       0
#
#                                                                                                                                          *w/peak  \
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                 0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                 1
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                 1
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                 0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                 1
# ...                                                                                                                                          ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                 0
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                 0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                 0
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                                                          *total
# stanza_i line_i line_ii combo_i combo_ii parse_i parse parse_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0       0        0       swws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                0
#                 1       0       1        0       swws  1        1      I        0          'aɪ      0      I        'aɪ      w                2
#                 2       0       2        0       swws  2        2      compare  0          kəm.'pɛr 0      com      kəm      w                1
#                 3       0       3        0       swws  3        2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                0
#                 0       0       0        1       wsws  0        0      Shall    0          'ʃæl     0      Shall    'ʃæl     w                2
# ...                                                                                                                                         ...
#          13     9       0       1        4       wss   1        9      to       0          tuː      0      to       tuː      s                1
#                 10      0       2        4       wss   2        10     thee     0          ðiː      0      thee     ðiː      s                1
#                 8       0       0        5       ssw   0        8      life     0          'laɪf    0      life     'laɪf    s                0
#                 9       0       1        5       ssw   1        9      to       0          tuː      0      to       tuː      s                1
#                 10      0       2        5       ssw   2        10     thee     0          ðiː      0      thee     ðiː      w                0
#
# [2058 rows x 12 columns]

# %% [markdown]
# ## Reconstructing lines

# %%
qcols=['stanza_i','line_i','combo_i','line_ii','syll_parse','parse']
dfap = df_all_parsed.reset_index()
dfap = dfap.set_index(qcols).sort_index()
dfap
# Out:
#                                                   combo_ii  parse_i  parse_ii  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww          0        5         0
#                                            swsw          0        3         0
#                                            swws          0        0         0
#                                 w          wssw          0        2         0
#                                            wsws          0        1         0
# ...                                                    ...      ...       ...
#          13     0       10      s          wss           2        4         2
#                                            wws           2        0         2
#                                 w          ssw           2        5         2
#                                            sww           2        1         2
#                                            wsw           2        2         2
#
#                                                   word_i word_str  word_ipa_i  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww        0    Shall           0
#                                            swsw        0    Shall           0
#                                            swws        0    Shall           0
#                                 w          wssw        0    Shall           0
#                                            wsws        0    Shall           0
# ...                                                  ...      ...         ...
#          13     0       10      s          wss        10     thee           0
#                                            wws        10     thee           0
#                                 w          ssw        10     thee           0
#                                            sww        10     thee           0
#                                            wsw        10     thee           0
#
#                                                  word_ipa  syll_i syll_str  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww      'ʃæl       0    Shall
#                                            swsw      'ʃæl       0    Shall
#                                            swws      'ʃæl       0    Shall
#                                 w          wssw      'ʃæl       0    Shall
#                                            wsws      'ʃæl       0    Shall
# ...                                                   ...     ...      ...
#          13     0       10      s          wss        ðiː       0     thee
#                                            wws        ðiː       0     thee
#                                 w          ssw        ðiː       0     thee
#                                            sww        ðiː       0     thee
#                                            wsw        ðiː       0     thee
#
#                                                  syll_ipa  prom_strength  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww      'ʃæl            1.0
#                                            swsw      'ʃæl            1.0
#                                            swws      'ʃæl            1.0
#                                 w          wssw      'ʃæl            1.0
#                                            wsws      'ʃæl            1.0
# ...                                                   ...            ...
#          13     0       10      s          wss        ðiː            NaN
#                                            wws        ðiː            NaN
#                                 w          ssw        ðiː            NaN
#                                            sww        ðiː            NaN
#                                            wsw        ðiː            NaN
#
#                                                   is_peak  is_stressed  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww         1            1
#                                            swsw         1            1
#                                            swws         1            1
#                                 w          wssw         1            1
#                                            wsws         1            1
# ...                                                   ...          ...
#          13     0       10      s          wss          0            0
#                                            wws          0            0
#                                 w          ssw          0            0
#                                            sww          0            0
#                                            wsw          0            0
#
#                                                   prom_stress  is_s  is_w  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww           1.0     1     0
#                                            swsw           1.0     1     0
#                                            swws           1.0     1     0
#                                 w          wssw           1.0     0     1
#                                            wsws           1.0     0     1
# ...                                                       ...   ...   ...
#          13     0       10      s          wss            0.0     1     0
#                                            wws            0.0     1     0
#                                 w          ssw            0.0     0     1
#                                            sww            0.0     0     1
#                                            wsw            0.0     0     1
#
#                                                   is_trough  is_unstressed  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww           0              0
#                                            swsw           0              0
#                                            swws           0              0
#                                 w          wssw           0              0
#                                            wsws           0              0
# ...                                                     ...            ...
#          13     0       10      s          wss            0              1
#                                            wws            0              1
#                                 w          ssw            0              1
#                                            sww            0              1
#                                            wsw            0              1
#
#                                                   *w/stressed  *s/unstressed  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww             0              0
#                                            swsw             0              0
#                                            swws             0              0
#                                 w          wssw             1              0
#                                            wsws             1              0
# ...                                                       ...            ...
#          13     0       10      s          wss              0              1
#                                            wws              0              1
#                                 w          ssw              0              0
#                                            sww              0              0
#                                            wsw              0              0
#
#                                                   *w/peak  *total
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww         0       0
#                                            swsw         0       0
#                                            swws         0       0
#                                 w          wssw         1       2
#                                            wsws         1       2
# ...                                                   ...     ...
#          13     0       10      s          wss          0       1
#                                            wws          0       1
#                                 w          ssw          0       0
#                                            sww          0       0
#                                            wsw          0       0
#
# [2058 rows x 22 columns]

# %%
# dfap.head(20)

# %%
# dfap.xs(0,level='line_i').xs(0,level='combo_i')

# %%
dfapdata = dfap.groupby(qcols).mean()
dfapdata
# Out:
#                                                   combo_ii  parse_i  parse_ii  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww        0.0      5.0       0.0
#                                            swsw        0.0      3.0       0.0
#                                            swws        0.0      0.0       0.0
#                                 w          wssw        0.0      2.0       0.0
#                                            wsws        0.0      1.0       0.0
# ...                                                    ...      ...       ...
#          13     0       10      s          wss         2.0      4.0       2.0
#                                            wws         2.0      0.0       2.0
#                                 w          ssw         2.0      5.0       2.0
#                                            sww         2.0      1.0       2.0
#                                            wsw         2.0      2.0       2.0
#
#                                                   word_i  word_ipa_i  syll_i  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww      0.0         0.0     0.0
#                                            swsw      0.0         0.0     0.0
#                                            swws      0.0         0.0     0.0
#                                 w          wssw      0.0         0.0     0.0
#                                            wsws      0.0         0.0     0.0
# ...                                                  ...         ...     ...
#          13     0       10      s          wss      10.0         0.0     0.0
#                                            wws      10.0         0.0     0.0
#                                 w          ssw      10.0         0.0     0.0
#                                            sww      10.0         0.0     0.0
#                                            wsw      10.0         0.0     0.0
#
#                                                   prom_strength  is_peak  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww             1.0      1.0
#                                            swsw             1.0      1.0
#                                            swws             1.0      1.0
#                                 w          wssw             1.0      1.0
#                                            wsws             1.0      1.0
# ...                                                         ...      ...
#          13     0       10      s          wss              NaN      0.0
#                                            wws              NaN      0.0
#                                 w          ssw              NaN      0.0
#                                            sww              NaN      0.0
#                                            wsw              NaN      0.0
#
#                                                   is_stressed  prom_stress  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww           1.0          1.0
#                                            swsw           1.0          1.0
#                                            swws           1.0          1.0
#                                 w          wssw           1.0          1.0
#                                            wsws           1.0          1.0
# ...                                                       ...          ...
#          13     0       10      s          wss            0.0          0.0
#                                            wws            0.0          0.0
#                                 w          ssw            0.0          0.0
#                                            sww            0.0          0.0
#                                            wsw            0.0          0.0
#
#                                                   is_s  is_w  is_trough  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww    1.0   0.0        0.0
#                                            swsw    1.0   0.0        0.0
#                                            swws    1.0   0.0        0.0
#                                 w          wssw    0.0   1.0        0.0
#                                            wsws    0.0   1.0        0.0
# ...                                                ...   ...        ...
#          13     0       10      s          wss     1.0   0.0        0.0
#                                            wws     1.0   0.0        0.0
#                                 w          ssw     0.0   1.0        0.0
#                                            sww     0.0   1.0        0.0
#                                            wsw     0.0   1.0        0.0
#
#                                                   is_unstressed  *w/stressed  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww             0.0          0.0
#                                            swsw             0.0          0.0
#                                            swws             0.0          0.0
#                                 w          wssw             0.0          1.0
#                                            wsws             0.0          1.0
# ...                                                         ...          ...
#          13     0       10      s          wss              1.0          0.0
#                                            wws              1.0          0.0
#                                 w          ssw              1.0          0.0
#                                            sww              1.0          0.0
#                                            wsw              1.0          0.0
#
#                                                   *s/unstressed  *w/peak  \
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww             0.0      0.0
#                                            swsw             0.0      0.0
#                                            swws             0.0      0.0
#                                 w          wssw             0.0      1.0
#                                            wsws             0.0      1.0
# ...                                                         ...      ...
#          13     0       10      s          wss              1.0      0.0
#                                            wws              1.0      0.0
#                                 w          ssw              0.0      0.0
#                                            sww              0.0      0.0
#                                            wsw              0.0      0.0
#
#                                                   *total
# stanza_i line_i combo_i line_ii syll_parse parse
# 0        0      0       0       s          ssww      0.0
#                                            swsw      0.0
#                                            swws      0.0
#                                 w          wssw      2.0
#                                            wsws      2.0
# ...                                                  ...
#          13     0       10      s          wss       1.0
#                                            wws       1.0
#                                 w          ssw       0.0
#                                            sww       0.0
#                                            wsw       0.0
#
# [1770 rows x 18 columns]

# %% [markdown]
# ### Plotting

# %%
figdf=dfapdata.reset_index()
# figdf=figdf[figdf.line_i==0]
figdf['line_ii_str']=['S'+str(x) for x in figdf.line_ii]
# figdf

# %%
import plotnine as p9
p9.ggplot(
    p9.aes(x='line_ii',y='*total',color='syll_parse'),
    data=figdf
) + p9.geom_line() + p9.facet_wrap('parse')
# Out:
# <ggplot: (8761392680953)>

# %% [markdown]
# ### Expanding possibilities

# %%
infogrp=['word_i', 'word_str', 'word_ipa_i', 'word_ipa', 'syll_i', 'syll_str', 'syll_ipa', 'syll_parse']
groupmean=['stanza_i','line_i','line_ii']
group0=['stanza_i','line_i']
group1=['line_ii']
group2=['syll_parse']

dfmean = df_all_parsed#.reset_index().groupby(groupmean).mean().reset_index()

dfexpand=pd.DataFrame()
for group0name,group0df in tqdm(list(dfmean.groupby(group0))):
    combo_opts = [
        [(ii,x) for ii,x in grp.groupby(group2)]
        for i,grp in group0df.groupby(group1)
    ]
    combos = list(product(*combo_opts))
    valid_combos = [
        combo
        for combo in combos
        if is_ok_parse(''.join(i for i,x in combo))
    ]
    print(len(valid_combos))
    
    for combo in valid_combos:
        combodf=pd.concat(y for x,y in combo)#.reset_index()
        combodfavg=combodf.groupby(groupmean + infogrp).mean()
        dfexpand=dfexpand.append(combodfavg)
#         display(combodfavg)
        
#         combodf=pd.concat(y for x,y in combo).reset_index()
#         display(combodf.head(25))
#         display(combodf.groupby(['line_ii','syll_parse']).mean().sort_index())
#         display(combodf.groupby(['line_ii','syll_parse']).mean().sort_index())
#         break
#     stop
dfexpand
# Out:
# (0, 0) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 1024
# 178
# (0, 1) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 4096
# 466
# (0, 2) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 2048
# 288
# (0, 3) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 8192
# 754
# (0, 4) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 2048
# 288
# (0, 5) [2, 2, 2, 2, 2, 2, 2]
# 128
# 42
# (0, 6) [2, 2, 2, 2, 2, 2, 2, 2, 2]
# 512
# 110
# (0, 7) [2, 2, 2, 2, 2]
# 32
# 16
# (0, 8) [2, 2, 2, 2, 2, 2, 2]
# 128
# 42
# (0, 9) [2, 2, 2, 2, 2]
# 32
# 16
# (0, 10) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 1024
# 178
# (0, 11) [2, 2, 2, 2]
# 16
# 10
# (0, 12) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 1024
# 178
# (0, 13) [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 1024
# 178
#                                                                                                  prom_strength  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                     1.0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                     1.0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                     1.0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                     1.0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                     1.0
# ...                                                                                                        ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                     NaN
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                     NaN
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                     NaN
#                 9       9      to       0          tuː      0      to       tuː      s                     NaN
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                     NaN
#
#                                                                                                  is_peak  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                 1
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                 1
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                 1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                 1
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                 1
# ...                                                                                                  ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                 0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                 0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                 0
#                 9       9      to       0          tuː      0      to       tuː      s                 0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                  is_stressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                     1
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                     1
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                     0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                     1
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                     0
# ...                                                                                                      ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                     0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                     1
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                     1
#                 9       9      to       0          tuː      0      to       tuː      s                     0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                  prom_stress  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                   1.0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                   1.0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                   0.0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                   1.0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                   0.0
# ...                                                                                                      ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                   0.0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                   1.0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                   1.0
#                 9       9      to       0          tuː      0      to       tuː      s                   0.0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                   0.0
#
#                                                                                                  is_s  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s              1
#                 1       1      I        0          'aɪ      0      I        'aɪ      s              1
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w              0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s              1
#                 4       3      thee     0          ðiː      0      thee     ðiː      s              1
# ...                                                                                               ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s              1
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w              0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w              0
#                 9       9      to       0          tuː      0      to       tuː      s              1
#                 10      10     thee     0          ðiː      0      thee     ðiː      w              0
#
#                                                                                                  is_w  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s              0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s              0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w              1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s              0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s              0
# ...                                                                                               ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s              0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w              1
#                 8       8      life     0          'laɪf    0      life     'laɪf    w              1
#                 9       9      to       0          tuː      0      to       tuː      s              0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w              1
#
#                                                                                                  is_trough  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                   0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                   0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                   0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                   0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                   0
# ...                                                                                                    ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                   0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                   0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                   0
#                 9       9      to       0          tuː      0      to       tuː      s                   0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                   0
#
#                                                                                                  is_unstressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                       0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                       0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                       1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                       0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                       1
# ...                                                                                                        ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                       1
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                       0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                       0
#                 9       9      to       0          tuː      0      to       tuː      s                       1
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                       1
#
#                                                                                                  *w/stressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                     0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                     0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                     0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                     0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                     0
# ...                                                                                                      ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                     0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                     1
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                     1
#                 9       9      to       0          tuː      0      to       tuː      s                     0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                     0
#
#                                                                                                  *s/unstressed  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                       0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                       0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                       0
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                       0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                       1
# ...                                                                                                        ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                       1
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                       0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                       0
#                 9       9      to       0          tuː      0      to       tuː      s                       1
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                       0
#
#                                                                                                  *w/peak  \
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                 0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                 0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                 1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                 0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                 0
# ...                                                                                                  ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                 0
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                 0
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                 0
#                 9       9      to       0          tuː      0      to       tuː      s                 0
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                 0
#
#                                                                                                  *total
# stanza_i line_i line_ii word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_parse
# 0        0      0       0      Shall    0          'ʃæl     0      Shall    'ʃæl     s                0
#                 1       1      I        0          'aɪ      0      I        'aɪ      s                0
#                 2       2      compare  0          kəm.'pɛr 0      com      kəm      w                1
#                 3       2      compare  0          kəm.'pɛr 1      pare     'pɛr     s                0
#                 4       3      thee     0          ðiː      0      thee     ðiː      s                1
# ...                                                                                                 ...
#          13     6       6      this     0          ðɪs      0      this     ðɪs      s                1
#                 7       7      gives    0          'gɪvz    0      gives    'gɪvz    w                1
#                 8       8      life     0          'laɪf    0      life     'laɪf    w                1
#                 9       9      to       0          tuː      0      to       tuː      s                1
#                 10      10     thee     0          ðiː      0      thee     ðiː      w                0
#
# [30628 rows x 12 columns]

# %%
print([len(x) for x in combo_opts])
# Out:
# [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]

# %%
combo

# %%
# combo_opts = [
#         [x for ii,x in grp.groupby(group2)]
#         for i,grp in df.groupby(group1)
#     ]

# # poss
# for combo in product(*combo_opts):
#     yield pd.concat(combo)
