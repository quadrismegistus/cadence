# %%
import sys; sys.path.insert(0,'/Users/ryan/github/prosodic/')
import sys; sys.path.insert(0,'/Users/ryan/github/cadence/')
from cadence.imports import *

# %%
text = Verse(sonnet,force=True)
text.data()
# Out:
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 5071.71it/s]
#                                                                                                                                           dep_head  ... word_nsyll
# para_i sent_i sentpart_i line_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress syll_weight            ...
# 1      1      1          1      1                How      how      1          haʊ       1      how      haʊ      U           H                   2  ...          1
#                                 2                heavy    heavy    1          'hɛ.viː   1      hea      'hɛ      P           L                   5  ...          2
#                                                                                         2      vy       viː      U           L                   5  ...          2
#                                 3                do       do       1          'duː      1      do       'duː     P           L                   5  ...          1
#                                                                    2          duː       1      do       duː      U           L                   5  ...          1
# ...                                                                                                                                            ...  ...        ...
#        2      15         14     81               and      and      1          ænd       1      and      ænd      U           H                  84  ...          1
#                                 82               my       my       1          maɪ       1      my       maɪ      U           H                  84  ...          1
#                                 83               joy      joy      1          'ʤɔɪ      1      joy      'ʤɔɪ     P           H                  84  ...          1
#                                 84               behind.  behind   1          bɪ.'haɪnd 1      be       bɪ       U           L                  79  ...          2
#                                                                                         2      hind     'haɪnd   P           H                  79  ...          2
#
# [170 rows x 27 columns]

# %%
# %%timeit
text.parse(force=True, num_proc=4)
# Out:
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 3775.25it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.06it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 24966.10it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.07it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 33026.02it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.06it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 34663.67it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.07it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 38479.85it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.07it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 38130.04it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.06it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 34379.54it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.06it/s]
# Iterating over paragraphs: 100%|██████████| 1/1 [00:00<00:00, 35848.75it/s]
# Metrically parsing line units [x4]: 100%|██████████| 14/14 [00:04<00:00,  3.06it/s]
# 4.7 s ± 7.26 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
import prosodic as p
p.config['print_to_screen']=0
ptext = p.Text(sonnet,meter='default_english')
ptext.parse()
# Out:
# 132 ms ± 5.16 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
ptext.bestParses()
# Out:
# [how|HEA|vy|DO|i|JOUR|ney|ON|the|WAY,
#  WHEN|what.i|SEEK|my|WEA|ry|TRA|vel|'||S|end,
#  doth|TEACH|that|EASE|and|THAT|re|POSE|to|SAY,
#  THUS.FAR|the|MILES|are|MEA|sured|FROM|thy|FRIEND,
#  the|BEAST|that|BEARS|me|TIRED|with.my|WOE,
#  PLODS.DUL|ly|ON|to|BEAR|that|WEIGHT|in.me,
#  as|IF|by.some|INS|tinct.the|WRETCH|did|KNOW,
#  his|RI|der|LOVED|not|SPEED.BE|ing|MADE|from.thee,
#  the|BLOO|dy|SPUR|can|NOT|pro|VOKE|him.on,
#  THAT|so|METIMES.AN|ger|THRUSTS|in|TO|his|HIDE,
#  which|HEA|vi|LY|he|AN|swers|WITH|a|GROAN,
#  more|SHARP|to|ME|than|SPURRING|to.his|SIDE,
#  for|THAT|same|GROAN|doth|PUT|this|IN|my|MIND,
#  my|GRIEF|lies|ON|ward|AND|my|JOY|be|HIND]
