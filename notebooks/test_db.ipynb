# %% [markdown]
# # Test scansion

# %%
import sys; sys.path.insert(0,'..')
from cadence.imports import *
# %load_ext line_profiler
# !rm -rf ~/.cadence/data/db.dc

# %%
txt="""
How heavy do I journey on the way,
When what I seek, my weary travel's end,
Doth teach that ease and that repose to say
'Thus far the miles are measured from thy friend!'
The beast that bears me, tired with my woe,
Plods dully on, to bear that weight in me,
As if by some instinct the wretch did know
His rider loved not speed, being made from thee:
The bloody spur cannot provoke him on
That sometimes anger thrusts into his hide;
Which heavily he answers with a groan,
More sharp to me than spurring to his side;
For that same groan doth put this in my mind;
My grief lies onward and my joy behind.
"""
s=txt.strip().split('\n')[0]
s="black birds into the woods"
s
# Out:
# 'black birds into the woods'

# %%
# %timeit parse(txt,force=False)
# %timeit parse(txt,force=True)
# Out:
# 275 ms ± 12.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 951 ms ± 21.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
s='black birds into the woods, can you believe it or not'

parse(s,prose=True)
# Out:
#                                                                                                                                                                                                                                                                                                                      *total  ...  prom_weight
# stanza_i line_i linepart_i parse_rank is_troch parse_i parse   parse_str                    combo_stress combo_ipa                     combo_i parse_is_bounded parse_bounded_by parse_pos_i parse_pos word_i word_str word_ipa_i word_ipa syll_i syll_str syll_ipa syll_stress syll_weight parse_syll_i parse_syll          ...
# 1        1      1          1          0        2       wswsws  black*|BIRDS|in|TO|the|WOODS P P UP U P   'blæk 'bɛːdz ɪn.'tuː ðə 'wʊdz 1       False                             1           w         1      black    1          'blæk    1      black    'blæk    P                       1            w              1.0  ...          NaN
# ...

# %%
scan(txt,prose=True)
# Out:
# Mapping do_scan_iter [x1]: 100%|██████████| 16/16 [00:00<00:00, 197.17it/s]
#                                                                                                                   is_funcword  ...  prom_weight
# stanza_i line_i linepart_i word_i word_str word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress syll_weight               ...
# 1        1      1          1      How      1          haʊ       1      How      haʊ      U                                  1  ...          NaN
#                            2      heavy    1          'hɛ.viː   1      hea      'hɛ      P                                  0  ...          NaN
#                                                                 2      vy       viː      U                                  0  ...          NaN
#                            3      do       1          'duː      1      do       'duː     P                                  0  ...          NaN
# ...

# %%
# %%timeit
scan(txt,progress=False)
# Out:
# ...
# Mapping do_scan_iter [x1]: 100%|██████████| 16/16 [00:00<00:00, 361.36it/s]
# 54.3 ms ± 1.61 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
parse(txt)
# Out:
# ...
# Mapping do_scan_iter [x1]: 100%|██████████| 16/16 [00:00<00:00, 52.29it/s]
# 312 ms ± 11.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
txtdf=scan(txt)
# Out:
# Mapping do_scan_iter [x1]: 100%|██████████| 16/16 [00:00<00:00, 330.70it/s]

# %%
# %%timeit
parse(txtdf)
# Out:
# 73.1 ms ± 3.42 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
