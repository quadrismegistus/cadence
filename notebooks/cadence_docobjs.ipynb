# %%
import sys; sys.path.insert(0,'/Users/ryan/github/prosodic/')
import sys; sys.path.insert(0,'/Users/ryan/github/cadence/')
from cadence.imports import *

# %%
# !rm -rf {PATH_DB}

# %%
t = Text(joyce_path,force=True,lim_paras=5)

# %%
t.para(11).data()
# Out:
#                                                                                                                           dep_head  ... word_nsyll
# sent_i sentpart_i line_i word_i word_pref word_str  word_tok  word_ipa_i word_ipa   syll_i syll_str syll_ipa syll_stress            ...
# 1      1          1      1                278                 NaN        NaN        NaN    NaN      NaN      NaN               6.0  ...        NaN
#                   2      2       \n       As        as        1.0        æz         1.0    as       æz       U                 4.0  ...        1.0
#                          3                her       her       1.0        hɛː        1.0    her      hɛː      U                 4.0  ...        1.0
#                          4                eyes      eyes      1.0        'aɪz       1.0    eyes     'aɪz     P                 1.0  ...        1.0
# ...

# %%
t.para(2)
# Out:
# <Paragraph #2: “Hoopsa boyaboy hoopsa!...” (3 sents, 9 words)>

# %%
text = Text(joyce_path)
t.para(2)
# Out:
# <Paragraph #2: “Hoopsa boyaboy hoopsa!...” (3 sents, 9 words)>

# %%
# text.para(10).mtree(1)

# %%
text.dat(44)
# Out:
#                                                                                                                               dep_head  ... word_nsyll
# para_i sent_i sentpart_i line_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress            ...
# 44     1      1          1      1                Onward   onward   1          'ɔːn.wɛːd 1      on       'ɔːn     P                 7.0  ...          2
#                                                                                         2      ward     wɛːd     U                 7.0  ...          2
#                                 2                to       to       1          tuː       1      to       tuː      U                 5.0  ...          1
#                                 3                the      the      1          ðə        1      the      ðə       U                 5.0  ...          1
# ...

# %%
para.data()
# Out:
#                                                                                                                              dep_head  ... word_nsyll
# sent_i sentpart_i line_i word_i word_pref word_str   word_tok   word_ipa_i word_ipa    syll_i syll_str syll_ipa syll_stress            ...
# 1      1          1      1                Deshil     deshil     1          'dɛs.hɪl    1      des      'dɛs     P                   0  ...          2
#                                                                                        2      hil      hɪl      U                   0  ...          2
#                          2                Holles     holles     1          'hɑlz       1      holles   'hɑlz    P                   1  ...          1
#                          3                Eamus.     eamus      1          'i.mʌs      1      ea       'i       P                   1  ...          2
# ...

# %%
para
# Out:
# <cd.Para(“Deshil Holles Eamus....”) [6s, 39w]>

# %%
text.data(lim_paras=3)
# Out:
# Iterating over paragraphs: 100%|██████████| 3/3 [00:00<00:00, 37.07it/s]
#                                                                                                                                              dep_head  ... pos_voice
# para_i sent_i sentpart_i line_i word_i word_pref word_str    word_tok    word_ipa_i word_ipa           syll_i syll_str syll_ipa syll_stress            ...
# 1      1      1          1      1                Deshil      deshil      1          'dɛs.hɪl           1      des      'dɛs     P                   0  ...       NaN
#                                                                                                        2      hil      hɪl      U                   0  ...       NaN
#                                 2                Holles      holles      1          'hɑlz              1      holles   'hɑlz    P                   1  ...       NaN
# ...

# %%
# !rm -rf {PATH_DB}

# %%
# %%timeit
test = Doc(joyce_para)
test.data()
# Out:
# 34.9 ms ± 629 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
Doc('Hello world').data()
# Out:
#                                                                                                                       dep_head  ... word_nsyll
# sent_i sentpart_i line_i word_i word_pref word_str word_tok word_ipa_i word_ipa syll_i syll_str syll_ipa syll_stress            ...
# 1      1          1      1                Hello    hello    1          hə.'loʊ  1      hel      hə       U                   2  ...          2
#                                                                                 2      lo       'loʊ     P                   2  ...          2
#                          2                world    world    1          'wɛːld   1      world    'wɛːld   P                   0  ...          1
#
# [3 rows x 22 columns]

# %%
Doc(sonnet.strip()).data()
# Out:
#                                                                                                                        dep_head  ... word_nsyll
# sent_i sentpart_i line_i word_i word_pref word_str word_tok word_ipa_i word_ipa  syll_i syll_str syll_ipa syll_stress            ...
# 1      1          1      1                How      how      1          haʊ       1      how      haʊ      U                   2  ...          1
#                          2                heavy    heavy    1          'hɛ.viː   1      hea      'hɛ      P                   5  ...          2
#                                                                                  2      vy       viː      U                   5  ...          2
#                          3                do       do       1          'duː      1      do       'duː     P                   5  ...          1
# ...
